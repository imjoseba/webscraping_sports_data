# %% [markdown]
# # Import libraries and packages

# %%
import json
import time 

import numpy as np
import pandas as pd

from bs4 import BeautifulSoup

from pydantic import BaseModel
from typing import List, Optional

from selenium import webdriver

from supabase import create_client, Client

# %%
driver = webdriver.Firefox()

# %%
# url to scrape
whoscored_url = "https://www.whoscored.com/Matches/1729371/Live/England-Premier-League-2023-2024-Nottingham-Forest-Liverpool"
driver.get(whoscored_url)

# %%
# create soup to parse
soup = BeautifulSoup(driver.page_source, "html.parser")

# %%
# select the script tag that contains the matchCentreData
element = soup.select_one("script:-soup-contains('matchCentreData')")

# %%
# parse the matchCentreData
matchdict = json.loads(element.text.split("matchCentreData: ")[1].split(",\n")[0])

# %%
# check the keys of the matchdict
matchdict.keys()
# Out:
# dict_keys(['playerIdNameDictionary', 'periodMinuteLimits', 'timeStamp', 'attendance', 'venueName', 'referee', 'weatherCode', 'elapsed', 'startTime', 'startDate', 'score', 'htScore', 'ftScore', 'etScore', 'pkScore', 'statusCode', 'periodCode', 'home', 'away', 'maxMinute', 'minuteExpanded', 'maxPeriod', 'expandedMinutes', 'expandedMaxMinute', 'periodEndMinutes', 'commonEvents', 'events', 'timeoutInSeconds'])

# %%
# check a random event
matchdict['events'][55]
# Out:
# {'id': 2653362563.0,
#  'eventId': 21,
#  'minute': 3,
#  'second': 43,
#  'teamId': 174,
#  'playerId': 124688,
#  'x': 16.4,
#  'y': 8.3,
#  'expandedMinute': 3,
#  'period': {'value': 1, 'displayName': 'FirstHalf'},
#  'type': {'value': 49, 'displayName': 'BallRecovery'},
#  'outcomeType': {'value': 1, 'displayName': 'Successful'},
#  'qualifiers': [],
#  'satisfiedEventsTypes': [93],
#  'isTouch': False}

# %%
match_events = matchdict['events']

# %%
# dictionary of the events
match_events
# Out:
# [{'id': 2653354707.0,
#   'eventId': 2,
#   'minute': 0,
#   'second': 0,
#   'teamId': 26,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2653354685.0,
#   'eventId': 2,
#   'minute': 0,
#   'second': 0,
#   'teamId': 174,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2653354759.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 0,
#   'teamId': 174,
#   'playerId': 342830,
#   'x': 50.0,
#   'y': 50.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '33.0'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '53.4'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '3.01'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '18.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 33.0,
#   'endY': 53.4},
#  {'id': 2653354815.0,
#   'eventId': 4,
#   'minute': 0,
#   'second': 3,
#   'teamId': 174,
#   'playerId': 445424,
#   'x': 33.9,
#   'y': 56.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '45.9'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '72.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.73'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '16.9'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 45.9,
#   'endY': 72.6},
#  {'id': 2653354867.0,
#   'eventId': 5,
#   'minute': 0,
#   'second': 5,
#   'teamId': 174,
#   'playerId': 334653,
#   'x': 44.7,
#   'y': 73.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.9'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.85'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '52.4'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '67.5'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 52.4,
#   'endY': 67.5},
#  {'id': 2653354887.0,
#   'eventId': 6,
#   'minute': 0,
#   'second': 6,
#   'teamId': 174,
#   'playerId': 332867,
#   'x': 53.4,
#   'y': 67.7,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.22'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '65.4'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '33.2'},
#    {'type': {'value': 156, 'displayName': 'LayOff'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '21.3'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 33.2,
#   'endY': 65.4},
#  {'id': 2653354967.0,
#   'eventId': 7,
#   'minute': 0,
#   'second': 8,
#   'teamId': 174,
#   'playerId': 445424,
#   'x': 25.0,
#   'y': 69.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '18.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '3.94'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '12.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '49.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 12.6,
#   'endY': 49.4},
#  {'id': 2653355015.0,
#   'eventId': 8,
#   'minute': 0,
#   'second': 12,
#   'teamId': 174,
#   'playerId': 78386,
#   'x': 14.9,
#   'y': 44.6,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '3.5'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.56'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '42.4'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '45.3'},
#    {'type': {'value': 1, 'displayName': 'Longball'}}],
#   'satisfiedEventsTypes': [91, 117, 124, 127, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 45.3,
#   'endY': 3.5},
#  {'id': 2653355095.0,
#   'eventId': 9,
#   'minute': 0,
#   'second': 16,
#   'teamId': 174,
#   'playerId': 386969,
#   'x': 54.9,
#   'y': 2.8,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Right'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '17.1'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.29'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '34.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '86.2'},
#    {'type': {'value': 1, 'displayName': 'Longball'}}],
#   'satisfiedEventsTypes': [91, 120, 128, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 86.2,
#   'endY': 17.1},
#  {'id': 2653355117.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 19,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 15.6,
#   'y': 83.7,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 12, 'displayName': 'Clearance'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.04'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '86.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '0.0'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '17.7'}],
#   'satisfiedEventsTypes': [91, 94, 95, 215],
#   'isTouch': True,
#   'endX': 0.0,
#   'endY': 86.3},
#  {'id': 2653355127.0,
#   'eventId': 4,
#   'minute': 0,
#   'second': 21,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 6.3,
#   'y': 84.6,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 6, 'displayName': 'CornerAwarded'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 73, 'displayName': 'MissLeft'}},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '10'}],
#   'satisfiedEventsTypes': [122],
#   'isTouch': False},
#  {'id': 2653355145.0,
#   'eventId': 10,
#   'minute': 0,
#   'second': 21,
#   'teamId': 174,
#   'playerId': 386969,
#   'x': 93.7,
#   'y': 15.4,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 6, 'displayName': 'CornerAwarded'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Right'},
#    {'type': {'value': 75, 'displayName': 'MissRight'}},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '4'}],
#   'satisfiedEventsTypes': [122],
#   'isTouch': False},
#  {'id': 2653356147.0,
#   'eventId': 11,
#   'minute': 0,
#   'second': 59,
#   'teamId': 174,
#   'playerId': 332867,
#   'x': 99.5,
#   'y': 0.5,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 20, 'displayName': 'RightFoot'}},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '42.8'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 6, 'displayName': 'CornerTaken'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '30.1'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '91.2'},
#    {'type': {'value': 2, 'displayName': 'Cross'}},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.86'}],
#   'satisfiedEventsTypes': [91, 137, 124, 126, 31, 33, 34, 35, 37, 217, 218],
#   'isTouch': True,
#   'endX': 91.2,
#   'endY': 42.8},
#  {'id': 2653356135.0,
#   'eventId': 5,
#   'minute': 1,
#   'second': 0,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 7.3,
#   'y': 54.8,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 44, 'displayName': 'Aerial'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '12'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [197, 200],
#   'isTouch': False},
#  {'id': 2653356181.0,
#   'eventId': 12,
#   'minute': 1,
#   'second': 0,
#   'teamId': 174,
#   'playerId': 124688,
#   'x': 92.7,
#   'y': 45.2,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 44, 'displayName': 'Aerial'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Center'},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '5'},
#    {'type': {'value': 286, 'displayName': 'Offensive'}}],
#   'satisfiedEventsTypes': [198, 199],
#   'isTouch': False},
#  {'id': 2653356169.0,
#   'eventId': 6,
#   'minute': 1,
#   'second': 0,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 5.8,
#   'y': 52.4,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 12, 'displayName': 'Clearance'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '15.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '20.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.16'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '56.0'},
#    {'type': {'value': 15, 'displayName': 'Head'}}],
#   'satisfiedEventsTypes': [91, 94, 95, 57, 215],
#   'isTouch': True,
#   'endX': 20.2,
#   'endY': 56.0},
#  {'id': 2653356283.0,
#   'eventId': 13,
#   'minute': 1,
#   'second': 2,
#   'teamId': 174,
#   'playerId': 386969,
#   'x': 75.0,
#   'y': 37.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '0.84'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '15.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '84.6'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '53.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 139, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 84.6,
#   'endY': 53.4},
#  {'id': 2653356271.0,
#   'eventId': 7,
#   'minute': 1,
#   'second': 4,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 15.0,
#   'y': 43.4,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 4, 'displayName': 'Foul'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 13, 'displayName': 'Foul'}},
#    {'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '14'}],
#   'satisfiedEventsTypes': [91, 63],
#   'isTouch': True},
#  {'id': 2653356297.0,
#   'eventId': 14,
#   'minute': 1,
#   'second': 4,
#   'teamId': 174,
#   'playerId': 342830,
#   'x': 85.0,
#   'y': 56.6,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 4, 'displayName': 'Foul'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 233,
#      'displayName': 'OppositeRelatedEvent'},
#     'value': '7'},
#    {'type': {'value': 286, 'displayName': 'Offensive'}},
#    {'type': {'value': 13, 'displayName': 'Foul'}},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [64],
#   'isTouch': False},
#  {'id': 2653357443.0,
#   'eventId': 9,
#   'minute': 1,
#   'second': 34,
#   'teamId': 26,
#   'playerId': 322176,
#   'x': 16.7,
#   'y': 40.3,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 5, 'displayName': 'FreekickTaken'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.37'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '23.8'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.2'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '25.0'}],
#   'satisfiedEventsTypes': [91, 117, 30, 132, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 25.0,
#   'endY': 23.8},
#  {'id': 2653357631.0,
#   'eventId': 10,
#   'minute': 1,
#   'second': 41,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 34.2,
#   'y': 21.4,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '27.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '59.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '24.1'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.96'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 24.1,
#   'endY': 59.0},
#  {'id': 2653357771.0,
#   'eventId': 11,
#   'minute': 1,
#   'second': 43,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 24.1,
#   'y': 59.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '17.0'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.04'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '45.2'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '12.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 17.0,
#   'endY': 45.2},
#  {'id': 2653357895.0,
#   'eventId': 12,
#   'minute': 1,
#   'second': 49,
#   'teamId': 26,
#   'playerId': 322176,
#   'x': 25.8,
#   'y': 42.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.22'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '36.0'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '14.3'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '22.1'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 36.0,
#   'endY': 14.3},
#  {'id': 2653357995.0,
#   'eventId': 13,
#   'minute': 1,
#   'second': 51,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 39.6,
#   'y': 14.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '0.58'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '72.0'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '47.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '40.6'}],
#   'satisfiedEventsTypes': [91, 120, 124, 128, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 72.0,
#   'endY': 47.5},
#  {'id': 2653358087.0,
#   'eventId': 15,
#   'minute': 1,
#   'second': 54,
#   'teamId': 174,
#   'playerId': 399490,
#   'x': 24.8,
#   'y': 50.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '36.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.23'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '55.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 139, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 36.9,
#   'endY': 55.2},
#  {'id': 2653358095.0,
#   'eventId': 16,
#   'minute': 1,
#   'second': 55,
#   'teamId': 174,
#   'playerId': 334653,
#   'x': 34.9,
#   'y': 49.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2653358161.0,
#   'eventId': 17,
#   'minute': 1,
#   'second': 57,
#   'teamId': 174,
#   'playerId': 334653,
#   'x': 29.1,
#   'y': 43.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.54'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '29.2'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.7'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '39.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 39.4,
#   'endY': 29.2},
#  {'id': 2653358183.0,
#   'eventId': 18,
#   'minute': 1,
#   'second': 58,
#   'teamId': 174,
#   'playerId': 124688,
#   'x': 39.4,
#   'y': 29.2,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 69],
#   'isTouch': True},
#  {'id': 2653358313.0,
#   'eventId': 14,
#   'minute': 1,
#   'second': 59,
#   'teamId': 26,
#   'playerId': 136451,
#   'x': 60.5,
#   'y': 64.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '61.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.01'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '68.1'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 68.1,
#   'endY': 61.4},
#  {'id': 2653358333.0,
#   'eventId': 15,
#   'minute': 2,
#   'second': 0,
#   'teamId': 26,
#   'playerId': 345319,
#   'x': 66.4,
#   'y': 60.3,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2653358363.0,
#   'eventId': 16,
#   'minute': 2,
#   'second': 0,
#   'teamId': 26,
#   'playerId': 345319,
#   'x': 65.7,
#   'y': 59.4,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '69.1'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '5.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.41'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '53.1'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 69.1,
#   'endY': 53.1},
#  {'id': 2653358433.0,
#   'eventId': 17,
#   'minute': 2,
#   'second': 2,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 69.4,
#   'y': 52.8,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '66.7'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.29'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '43.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '6.9'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 35, 38, 217, 218],
#   'isTouch': True,
#   'endX': 66.7,
#   'endY': 43.6},
#  {'id': 2653358477.0,
#   'eventId': 18,
#   'minute': 2,
#   'second': 3,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 66.7,
#   'y': 43.6,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '64.5'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '5.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.00'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '51.0'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 35, 37, 216, 218],
#   'isTouch': True,
#   'endX': 64.5,
#   'endY': 51.0},
#  {'id': 2653358563.0,
#   'eventId': 19,
#   'minute': 2,
#   'second': 4,
#   'teamId': 26,
#   'playerId': 345319,
#   'x': 64.5,
#   'y': 51.6,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Left'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '21.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '70.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '81.0'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.26'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 70.7,
#   'endY': 81.0},
#  {'id': 2653358801.0,
#   'eventId': 20,
#   'minute': 2,
#   'second': 7,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 74.7,
#   'y': 78.2,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.46'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '100.0'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 72, 'displayName': 'LeftFoot'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '34.7'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 2, 'displayName': 'Cross'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '40.5'}],
#   'satisfiedEventsTypes': [91, 138, 124, 126, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 100.0,
#   'endY': 34.7},
#  {'id': 2653360071.0,
#   'eventId': 20,
#   'minute': 2,
#   'second': 38,
#   'teamId': 174,
#   'playerId': 78386,
#   'x': 4.7,
#   'y': 60.9,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '75.2'},
#    {'type': {'value': 124, 'displayName': 'GoalKick'}},
#    {'type': {'value': 74, 'displayName': 'MissHigh'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.11'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '75.2'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '41.6'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [91, 120, 128, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 75.2,
#   'endY': 41.6},
#  {'id': 2653360043.0,
#   'eventId': 22,
#   'minute': 2,
#   'second': 43,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 29.6,
#   'y': 48.7,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2653360211.0,
#   'eventId': 23,
#   'minute': 2,
#   'second': 45,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 28.1,
#   'y': 54.8,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.53'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '29.1'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '92.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '25.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 29.1,
#   'endY': 92.6},
#  {'id': 2653360473.0,
#   'eventId': 24,
#   'minute': 2,
#   'second': 47,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 28.5,
#   'y': 90.9,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '4.02'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '9.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '55.7'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '31.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 9.5,
#   'endY': 55.7},
#  {'id': 2653360683.0,
#   'eventId': 25,
#   'minute': 2,
#   'second': 54,
#   'teamId': 26,
#   'playerId': 322176,
#   'x': 22.7,
#   'y': 44.9,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '18.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.06'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '19.1'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '28.7'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 28.7,
#   'endY': 19.1},
#  {'id': 2653360759.0,
#   'eventId': 26,
#   'minute': 2,
#   'second': 59,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 30.0,
#   'y': 16.4,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '2.11'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '15.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '36.1'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '22.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 22.4,
#   'endY': 36.1},
#  {'id': 2653360891.0,
#   'eventId': 27,
#   'minute': 3,
#   'second': 1,
#   'teamId': 26,
#   'playerId': 322176,
#   'x': 23.4,
#   'y': 37.6,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '1.49'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '24.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '20.1'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '67.1'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 24.9,
#   'endY': 67.1},
#  {'id': 2653361135.0,
#   'eventId': 28,
#   'minute': 3,
#   'second': 4,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 23.7,
#   'y': 65.4,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '29.8'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '30.5'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '22.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.95'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 30.5,
#   'endY': 22.9},
#  {'id': 2653361249.0,
#   'eventId': 29,
#   'minute': 3,
#   'second': 9,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 41.0,
#   'y': 22.9,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '29.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '55.7'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.29'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '16.1'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 55.7,
#   'endY': 29.6},
#  {'id': 2653361357.0,
#   'eventId': 30,
#   'minute': 3,
#   'second': 11,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 53.7,
#   'y': 28.3,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.97'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '13.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.2'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '45.2'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 216, 218],
#   'isTouch': True,
#   'endX': 45.2,
#   'endY': 13.9},
#  {'id': 2653361433.0,
#   'eventId': 31,
#   'minute': 3,
#   'second': 15,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 45.5,
#   'y': 13.3,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '11.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '29.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '48.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.25'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 48.9,
#   'endY': 29.3},
#  {'id': 2653361605.0,
#   'eventId': 32,
#   'minute': 3,
#   'second': 17,
#   'teamId': 26,
#   'playerId': 345319,
#   'x': 48.8,
#   'y': 31.4,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '34.5'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.79'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '41.5'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '80.9'},
#    {'type': {'value': 1, 'displayName': 'Longball'}}],
#   'satisfiedEventsTypes': [91, 117, 127, 35, 37, 216, 218],
#   'isTouch': True,
#   'endX': 41.5,
#   'endY': 80.9},
#  {'id': 2653361711.0,
#   'eventId': 33,
#   'minute': 3,
#   'second': 19,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 41.4,
#   'y': 81.0,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '64.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '26.7'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.39'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '96.0'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 64.9,
#   'endY': 96.0},
#  {'id': 2653361793.0,
#   'eventId': 34,
#   'minute': 3,
#   'second': 24,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 65.4,
#   'y': 90.9,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Center'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '3.77'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '18.0'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '75.3'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '51.5'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 35, 38, 216, 218],
#   'isTouch': True,
#   'endX': 51.5,
#   'endY': 75.3},
#  {'id': 2653361879.0,
#   'eventId': 35,
#   'minute': 3,
#   'second': 26,
#   'teamId': 26,
#   'playerId': 136451,
#   'x': 46.2,
#   'y': 72.9,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '22.4'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '46.3'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.72'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '40.0'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 46.3,
#   'endY': 40.0},
#  {'id': 2653362081.0,
#   'eventId': 36,
#   'minute': 3,
#   'second': 28,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 46.3,
#   'y': 40.0,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.42'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '17.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '20.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '58.7'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 58.7,
#   'endY': 17.6},
#  {'id': 2653362205.0,
#   'eventId': 37,
#   'minute': 3,
#   'second': 32,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 70.4,
#   'y': 13.0,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Right'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '4.0'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '69.3'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '6.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.53'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 35, 38, 217, 218],
#   'isTouch': True,
#   'endX': 69.3,
#   'endY': 4.0},
#  {'id': 2653362237.0,
#   'eventId': 38,
#   'minute': 3,
#   'second': 34,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 67.8,
#   'y': 8.5,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.30'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '17.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '62.4'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 35, 37, 216, 218],
#   'isTouch': True,
#   'endX': 62.4,
#   'endY': 17.9},
#  {'id': 2653362483.0,
#   'eventId': 39,
#   'minute': 3,
#   'second': 38,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 57.0,
#   'y': 35.0,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '97.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.09'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '78.2'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '48.1'},
#    {'type': {'value': 1, 'displayName': 'Longball'}}],
#   'satisfiedEventsTypes': [91, 119, 117, 124, 127, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 78.2,
#   'endY': 97.7},
#  {'id': 2653362527.0,
#   'eventId': 40,
#   'minute': 3,
#   'second': 41,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 79.2,
#   'y': 96.9,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '89.7'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.82'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '11.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '88.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 120, 29, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 88.6,
#   'endY': 89.7},
#  {'id': 2653362563.0,
#   'eventId': 21,
#   'minute': 3,
#   'second': 43,
#   'teamId': 174,
#   'playerId': 124688,
#   'x': 16.4,
#   'y': 8.3,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2653362649.0,
#   'eventId': 22,
#   'minute': 3,
#   'second': 44,
#   'teamId': 174,
#   'playerId': 124688,
#   'x': 14.0,
#   'y': 5.5,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.37'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '12.8'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '26.1'}],
#   'satisfiedEventsTypes': [91, 118, 120, 29, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 26.1,
#   'endY': 12.8},
#  {'id': 2653362747.0,
#   'eventId': 41,
#   'minute': 3,
#   'second': 46,
#   'teamId': 26,
#   'playerId': 136451,
#   'x': 74.0,
#   'y': 79.8,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '5.3'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.34'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '82.4'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '78.8'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 78.8,
#   'endY': 82.4},
#  {'id': 2653362819.0,
#   'eventId': 42,
#   'minute': 3,
#   'second': 48,
#   'teamId': 26,
#   'playerId': 377168,
#   'x': 78.7,
#   'y': 80.0,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '18.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '52.8'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '81.2'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.85'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 81.2,
#   'endY': 52.8},
#  {'id': 2653362833.0,
#   'eventId': 43,
#   'minute': 3,
#   'second': 49,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 80.2,
#   'y': 50.3,
#   'expandedMinute': 3,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 50, 'displayName': 'Dispossessed'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
# ...
#   'satisfiedEventsTypes': [91, 117, 30, 139, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 44.3,
#   'endY': 57.5},
#  {'id': 2653502793.0,
#   'eventId': 675,
#   'minute': 54,
#   'second': 15,
#   'teamId': 26,
#   'playerId': 136451,
#   'x': 44.2,
#   'y': 57.6,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '15.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '57.1'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.52'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '68.9'}],
#   'satisfiedEventsTypes': [91, 120, 29, 139, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 57.1,
#   'endY': 68.9},
#  {'id': 2653502953.0,
#   'eventId': 435,
#   'minute': 54,
#   'second': 17,
#   'teamId': 174,
#   'playerId': 342830,
#   'x': 40.7,
#   'y': 28.9,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Right'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '16.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.63'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '14.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '53.2'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 139, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 53.2,
#   'endY': 14.0},
#  {'id': 2653503123.0,
#   'eventId': 436,
#   'minute': 54,
#   'second': 21,
#   'teamId': 174,
#   'playerId': 124688,
#   'x': 56.3,
#   'y': 2.9,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '68.3'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '14.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.57'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '15.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 68.3,
#   'endY': 14.9},
#  {'id': 2653503215.0,
#   'eventId': 437,
#   'minute': 54,
#   'second': 26,
#   'teamId': 174,
#   'playerId': 386969,
#   'x': 74.5,
#   'y': 21.6,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '87.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.0'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.29'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '27.4'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 87.3,
#   'endY': 27.4},
#  {'id': 2653503313.0,
#   'eventId': 439,
#   'minute': 54,
#   'second': 27,
#   'teamId': 174,
#   'playerId': 332867,
#   'x': 91.6,
#   'y': 31.6,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 50, 'displayName': 'Dispossessed'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 233,
#      'displayName': 'OppositeRelatedEvent'},
#     'value': '677'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 286, 'displayName': 'Offensive'}}],
#   'satisfiedEventsTypes': [91, 70],
#   'isTouch': True},
#  {'id': 2653503905.0,
#   'eventId': 677,
#   'minute': 54,
#   'second': 28,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 8.4,
#   'y': 68.4,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 7, 'displayName': 'Tackle'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '439'}],
#   'satisfiedEventsTypes': [91, 142],
#   'isTouch': True},
#  {'id': 2653504051.0,
#   'eventId': 441,
#   'minute': 54,
#   'second': 28,
#   'teamId': 174,
#   'playerId': 332867,
#   'x': 92.7,
#   'y': 27.4,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Center'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91],
#   'isTouch': True},
#  {'id': 2653504293.0,
#   'eventId': 678,
#   'minute': 54,
#   'second': 41,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 5.3,
#   'y': 58.1,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.46'},
#    {'type': {'value': 124, 'displayName': 'GoalKick'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '47.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '7.2'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '3.6'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 3.6,
#   'endY': 47.9},
#  {'id': 2653765015.0,
#   'eventId': 1120,
#   'minute': 54,
#   'second': 45,
#   'teamId': 26,
#   'playerId': 322176,
#   'x': 10.6,
#   'y': 48.7,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '68.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.44'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '12.3'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.6'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 12.3,
#   'endY': 68.6},
#  {'id': 2653504303.0,
#   'eventId': 679,
#   'minute': 54,
#   'second': 51,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 21.7,
#   'y': 62.6,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '4.91'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '26.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '26.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '25.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 26.5,
#   'endY': 26.0},
#  {'id': 2653504403.0,
#   'eventId': 680,
#   'minute': 54,
#   'second': 53,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 26.5,
#   'y': 26.0,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '17.1'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '45.5'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.25'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '16.2'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 16.2,
#   'endY': 45.5},
#  {'id': 2653504461.0,
#   'eventId': 681,
#   'minute': 54,
#   'second': 57,
#   'teamId': 26,
#   'playerId': 322176,
#   'x': 23.7,
#   'y': 51.0,
#   'expandedMinute': 56,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '1.18'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '60.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '6.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '26.1'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 26.1,
#   'endY': 60.0},
#  {'id': 2653504779.0,
#   'eventId': 682,
#   'minute': 55,
#   'second': 3,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 30.0,
#   'y': 56.1,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '37.0'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.06'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '26.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '21.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 37.0,
#   'endY': 26.0},
#  {'id': 2653504919.0,
#   'eventId': 683,
#   'minute': 55,
#   'second': 10,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 53.8,
#   'y': 9.7,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '60.6'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '5.9'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.94'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '7.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 60.6,
#   'endY': 5.9},
#  {'id': 2653505023.0,
#   'eventId': 684,
#   'minute': 55,
#   'second': 13,
#   'teamId': 26,
#   'playerId': 377168,
#   'x': 50.9,
#   'y': 4.6,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '30.4'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.35'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '24.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '34.4'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 216, 218],
#   'isTouch': True,
#   'endX': 34.4,
#   'endY': 30.4},
#  {'id': 2653505109.0,
#   'eventId': 685,
#   'minute': 55,
#   'second': 16,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 36.7,
#   'y': 34.4,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '70.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.41'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '40.5'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '24.9'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 40.5,
#   'endY': 70.5},
#  {'id': 2653505215.0,
#   'eventId': 686,
#   'minute': 55,
#   'second': 18,
#   'teamId': 26,
#   'playerId': 136451,
#   'x': 44.7,
#   'y': 72.8,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '59.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.83'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '98.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '23.6'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 59.9,
#   'endY': 98.4},
#  {'id': 2653505405.0,
#   'eventId': 687,
#   'minute': 55,
#   'second': 24,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 68.4,
#   'y': 75.2,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '20.8'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '49.0'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.26'},
#    {'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '78.7'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 78.7,
#   'endY': 49.0},
#  {'id': 2653505451.0,
#   'eventId': 688,
#   'minute': 55,
#   'second': 25,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 78.7,
#   'y': 49.0,
#   'expandedMinute': 57,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '64.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.02'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '11.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '74.0'}],
#   'satisfiedEventsTypes': [91, 120, 29, 35, 37, 217, 218],
#   'isTouch': True,
#   'endX': 74.0,
#   'endY': 64.2},
#  ...]

# %%
match_players = matchdict['home']['players'] + matchdict['away']['players']
match_players
# Out:
# [{'playerId': 78386,
#   'shirtNo': 26,
#   'name': 'Matz Sels',
#   'position': 'GK',
#   'height': 188,
#   'weight': 75,
#   'age': 32,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'totalSaves': {'96': 1.0},
#    'parriedSafe': {'96': 1.0},
#    'possession': {'0': 1.0,
#     '2': 1.0,
#     '6': 1.0,
#     '8': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '24': 1.0,
#     '32': 1.0,
#     '34': 1.0,
#     '35': 1.0,
#     '49': 1.0,
#     '52': 1.0,
#     '53': 1.0,
#     '56': 1.0,
#     '60': 1.0,
#     '62': 2.0,
#     '66': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '74': 1.0,
#     '77': 1.0,
#     '89': 1.0,
#     '93': 2.0,
#     '96': 1.0},
#    'ratings': {'0': 6.01,
#     '2': 6.0,
#     '6': 6.01,
#     '8': 6.02,
#     '13': 6.03,
#     '15': 6.03,
#     '18': 6.04,
#     '19': 6.05,
#     '24': 6.04,
#     '32': 6.05,
#     '34': 6.04,
#     '35': 6.06,
#     '49': 6.04,
#     '52': 6.05,
#     '53': 6.04,
#     '56': 6.03,
#     '59': 6.03,
#     '60': 6.02,
#     '62': 6.0,
#     '66': 5.99,
#     '69': 6.0,
#     '72': 5.99,
#     '74': 5.98,
#     '77': 5.99,
#     '86': 6.11,
#     '89': 6.1,
#     '93': 6.08,
#     '96': 6.35,
#     '100': 6.08},
#    'touches': {'0': 1.0,
#     '2': 1.0,
#     '6': 1.0,
#     '8': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '24': 1.0,
#     '32': 1.0,
#     '34': 1.0,
#     '35': 1.0,
#     '49': 1.0,
#     '52': 1.0,
#     '53': 1.0,
#     '56': 1.0,
#     '60': 1.0,
#     '62': 2.0,
#     '66': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '74': 1.0,
#     '77': 1.0,
#     '86': 1.0,
#     '89': 1.0,
#     '93': 2.0,
#     '96': 2.0},
#    'passesTotal': {'0': 1.0,
#     '6': 1.0,
#     '8': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '32': 1.0,
#     '35': 1.0,
#     '52': 1.0,
#     '77': 1.0,
#     '2': 1.0,
#     '24': 1.0,
#     '34': 1.0,
#     '49': 1.0,
#     '53': 1.0,
#     '56': 1.0,
#     '60': 1.0,
#     '62': 2.0,
#     '66': 1.0,
#     '72': 1.0,
#     '74': 1.0,
#     '89': 1.0,
#     '93': 2.0,
#     '96': 1.0},
#    'passesAccurate': {'0': 1.0,
#     '6': 1.0,
#     '8': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '32': 1.0,
#     '35': 1.0,
#     '52': 1.0,
#     '77': 1.0},
#    'passSuccess': {'0': 100.0,
#     '6': 100.0,
#     '8': 100.0,
#     '13': 100.0,
#     '15': 100.0,
#     '18': 100.0,
#     '19': 100.0,
#     '32': 100.0,
#     '35': 100.0,
#     '52': 100.0,
#     '77': 100.0,
#     '2': 0.0,
#     '24': 0.0,
#     '34': 0.0,
#     '49': 0.0,
#     '53': 0.0,
#     '56': 0.0,
#     '60': 0.0,
#     '62': 0.0,
#     '66': 0.0,
#     '72': 0.0,
#     '74': 0.0,
#     '89': 0.0,
#     '93': 0.0,
#     '96': 0.0},
#    'aerialsTotal': {'86': 1.0},
#    'aerialsWon': {'86': 1.0},
#    'defensiveAerials': {'86': 1.0}}},
#  {'playerId': 386969,
#   'shirtNo': 7,
#   'name': 'Neco Williams',
#   'position': 'DR',
#   'height': 183,
#   'weight': 72,
#   'age': 22,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 1.0,
#     '1': 1.0,
#     '6': 1.0,
#     '7': 1.0,
#     '12': 1.0,
#     '13': 2.0,
#     '19': 1.0,
#     '33': 1.0,
#     '34': 1.0,
#     '40': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '50': 3.0,
#     '53': 1.0,
#     '56': 1.0,
#     '60': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '71': 2.0,
#     '99': 1.0},
#    'ratings': {'0': 5.99,
#     '1': 5.99,
#     '5': 6.04,
#     '6': 6.13,
#     '7': 6.12,
#     '8': 6.21,
#     '9': 6.17,
#     '11': 6.15,
#     '12': 6.15,
#     '13': 6.24,
#     '15': 6.45,
#     '17': 6.57,
#     '19': 6.56,
#     '33': 6.56,
#     '34': 6.56,
#     '36': 6.54,
#     '37': 6.64,
#     '40': 6.62,
#     '47': 6.61,
#     '48': 6.6,
#     '50': 6.59,
#     '53': 6.58,
#     '56': 6.58,
#     '59': 6.63,
#     '60': 6.65,
#     '63': 6.78,
#     '66': 6.78,
#     '70': 6.78,
#     '71': 6.93,
#     '75': 6.9,
#     '76': 6.95,
#     '92': 7.03,
#     '95': 7.08,
#     '99': 7.07,
#     '100': 6.89},
#    'clearances': {'5': 1.0, '17': 1.0, '59': 1.0, '76': 1.0},
#    'interceptions': {'37': 1.0},
#    'touches': {'0': 1.0,
#     '1': 1.0,
#     '5': 1.0,
#     '6': 1.0,
#     '7': 1.0,
#     '8': 1.0,
#     '9': 2.0,
#     '11': 3.0,
#     '12': 2.0,
#     '13': 2.0,
#     '15': 2.0,
#     '17': 2.0,
#     '19': 1.0,
#     '30': 1.0,
#     '33': 1.0,
#     '34': 1.0,
#     '35': 1.0,
#     '36': 2.0,
#     '37': 1.0,
#     '40': 1.0,
#     '41': 1.0,
#     '47': 5.0,
#     '48': 1.0,
#     '50': 4.0,
#     '53': 3.0,
#     '56': 1.0,
#     '59': 1.0,
#     '60': 2.0,
#     '63': 1.0,
#     '66': 1.0,
#     '70': 3.0,
#     '71': 5.0,
#     '75': 1.0,
#     '76': 1.0,
#     '92': 1.0,
#     '95': 1.0,
#     '99': 1.0},
#    'passesTotal': {'1': 1.0,
#     '6': 1.0,
#     '12': 1.0,
#     '13': 2.0,
#     '33': 1.0,
#     '34': 1.0,
#     '47': 1.0,
#     '50': 2.0,
#     '56': 1.0,
#     '60': 1.0,
#     '66': 1.0,
#     '71': 2.0,
#     '0': 1.0,
#     '7': 1.0,
#     '19': 1.0,
#     '40': 1.0,
#     '53': 1.0,
#     '70': 1.0,
#     '99': 1.0},
#    'passesAccurate': {'1': 1.0,
#     '6': 1.0,
#     '12': 1.0,
#     '13': 2.0,
#     '33': 1.0,
#     '34': 1.0,
#     '47': 1.0,
#     '50': 1.0,
#     '56': 1.0,
#     '60': 1.0,
#     '66': 1.0,
#     '71': 2.0},
#    'passSuccess': {'1': 100.0,
#     '6': 100.0,
#     '12': 100.0,
#     '13': 100.0,
#     '33': 100.0,
#     '34': 100.0,
#     '47': 100.0,
#     '50': 50.0,
#     '56': 100.0,
#     '60': 100.0,
#     '66': 100.0,
#     '71': 100.0,
#     '0': 0.0,
#     '7': 0.0,
#     '19': 0.0,
#     '40': 0.0,
#     '53': 0.0,
#     '70': 0.0,
#     '99': 0.0},
#    'aerialsTotal': {'6': 1.0, '13': 1.0, '17': 1.0, '60': 1.0, '100': 1.0},
#    'aerialsWon': {'6': 1.0, '13': 1.0},
#    'aerialSuccess': {'17': 0.0, '60': 0.0, '100': 0.0},
#    'defensiveAerials': {'6': 1.0, '13': 1.0, '17': 1.0, '60': 1.0, '100': 1.0},
#    'cornersTotal': {'0': 1.0},
#    'throwInsTotal': {'9': 1.0,
#     '11': 2.0,
#     '12': 1.0,
#     '30': 1.0,
#     '35': 1.0,
#     '41': 1.0,
#     '47': 2.0,
#     '53': 2.0,
#     '70': 2.0},
#    'throwInsAccurate': {'9': 1.0, '12': 1.0, '35': 1.0, '47': 1.0, '53': 2.0},
#    'tacklesTotal': {'15': 2.0, '63': 1.0, '8': 1.0},
#    'tackleSuccessful': {'15': 2.0, '63': 1.0, '8': 1.0},
#    'tackleSuccess': {'15': 100.0, '63': 100.0, '8': 100.0},
#    'dribblesWon': {'71': 1.0},
#    'dribblesAttempted': {'71': 2.0, '47': 1.0},
#    'dribblesLost': {'47': 1.0, '71': 1.0},
#    'dribbleSuccess': {'71': 50.0, '47': 0.0},
#    'dispossessed': {'11': 1.0}}},
#  {'playerId': 399490,
#   'shirtNo': 32,
#   'name': 'Andrew Omobamidele',
#   'position': 'DC',
#   'height': 188,
#   'weight': 0,
#   'age': 21,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'1': 1.0,
#     '13': 1.0,
#     '20': 1.0,
#     '28': 1.0,
#     '33': 2.0,
#     '34': 3.0,
#     '38': 1.0,
#     '41': 2.0,
#     '47': 1.0,
#     '50': 2.0,
#     '53': 1.0,
#     '60': 1.0,
#     '62': 1.0,
#     '66': 1.0,
#     '102': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 6.0,
#     '13': 6.0,
#     '16': 6.09,
#     '20': 6.09,
#     '23': 6.14,
#     '26': 6.22,
#     '28': 6.3,
#     '33': 6.31,
#     '34': 6.31,
#     '38': 6.32,
#     '41': 6.37,
#     '47': 6.37,
#     '50': 6.37,
#     '51': 6.95,
#     '53': 6.95,
#     '57': 7.09,
#     '60': 7.13,
#     '62': 7.2,
#     '64': 7.3,
#     '66': 7.36,
#     '91': 7.5,
#     '100': 7.36,
#     '102': 7.36},
#    'clearances': {'23': 1.0,
#     '41': 1.0,
#     '60': 1.0,
#     '64': 2.0,
#     '66': 1.0,
#     '91': 1.0,
#     '100': 1.0},
#    'interceptions': {'91': 1.0},
#    'touches': {'1': 1.0,
#     '13': 1.0,
#     '16': 1.0,
#     '20': 1.0,
#     '23': 1.0,
#     '26': 1.0,
#     '28': 2.0,
#     '33': 2.0,
#     '34': 3.0,
#     '38': 1.0,
#     '41': 3.0,
#     '47': 1.0,
#     '50': 2.0,
#     '51': 1.0,
#     '53': 1.0,
#     '57': 1.0,
#     '60': 2.0,
#     '62': 2.0,
#     '64': 2.0,
#     '66': 2.0,
#     '73': 1.0,
#     '91': 2.0,
#     '100': 1.0,
#     '102': 1.0},
#    'passesTotal': {'1': 1.0,
#     '13': 1.0,
#     '20': 1.0,
#     '33': 2.0,
#     '34': 3.0,
#     '38': 1.0,
#     '41': 2.0,
#     '50': 2.0,
#     '53': 1.0,
#     '66': 1.0,
#     '102': 1.0,
#     '28': 1.0,
#     '47': 1.0,
#     '60': 1.0,
#     '62': 1.0},
#    'passesAccurate': {'1': 1.0,
#     '13': 1.0,
#     '20': 1.0,
#     '33': 2.0,
#     '34': 3.0,
#     '38': 1.0,
#     '41': 2.0,
#     '50': 2.0,
#     '53': 1.0,
#     '66': 1.0,
#     '102': 1.0},
#    'passSuccess': {'1': 100.0,
#     '13': 100.0,
#     '20': 100.0,
#     '33': 100.0,
#     '34': 100.0,
#     '38': 100.0,
#     '41': 100.0,
#     '50': 100.0,
#     '53': 100.0,
#     '66': 100.0,
#     '102': 100.0,
#     '28': 0.0,
#     '47': 0.0,
#     '60': 0.0,
#     '62': 0.0},
#    'tacklesTotal': {'57': 1.0, '28': 1.0, '62': 1.0},
#    'tackleSuccessful': {'57': 1.0, '28': 1.0, '62': 1.0},
#    'tackleSuccess': {'57': 100.0, '28': 100.0, '62': 100.0}}},
#  {'playerId': 445424,
#   'shirtNo': 40,
#   'name': 'Murillo',
#   'position': 'DC',
#   'height': 180,
#   'weight': 75,
#   'age': 21,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 2.0,
#     '8': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 1.0,
#     '20': 2.0,
#     '24': 1.0,
#     '33': 2.0,
#     '34': 2.0,
#     '35': 1.0,
#     '38': 1.0,
#     '39': 1.0,
#     '42': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '49': 1.0,
#     '50': 1.0,
#     '52': 1.0,
#     '53': 1.0,
#     '54': 1.0,
#     '56': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '71': 3.0,
#     '75': 2.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '102': 1.0},
#    'ratings': {'0': 6.0,
#     '3': 6.09,
#     '5': 6.1,
#     '8': 6.1,
#     '10': 6.09,
#     '12': 6.11,
#     '13': 6.11,
#     '15': 6.11,
#     '18': 6.11,
#     '19': 6.16,
#     '20': 6.24,
#     '24': 6.24,
#     '25': 6.29,
#     '26': 6.37,
#     '33': 6.38,
#     '34': 6.37,
#     '35': 6.38,
#     '38': 6.37,
#     '39': 6.36,
#     '42': 6.33,
#     '47': 6.34,
#     '48': 6.5,
#     '49': 6.55,
#     '50': 6.55,
#     '52': 6.64,
#     '53': 6.63,
#     '54': 6.64,
#     '56': 6.64,
#     '60': 6.74,
#     '66': 6.73,
#     '67': 6.73,
#     '69': 6.73,
#     '71': 6.74,
#     '75': 6.74,
#     '77': 6.75,
#     '81': 6.74,
#     '83': 6.75,
#     '84': 6.8,
#     '100': 6.6,
#     '102': 6.6},
#    'clearances': {'19': 1.0, '25': 1.0, '49': 1.0, '84': 1.0},
#    'interceptions': {'60': 1.0},
#    'touches': {'0': 2.0,
#     '3': 1.0,
#     '8': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '20': 3.0,
#     '24': 1.0,
#     '25': 1.0,
#     '26': 1.0,
#     '33': 2.0,
#     '34': 2.0,
#     '35': 1.0,
#     '38': 1.0,
#     '39': 1.0,
#     '42': 1.0,
#     '47': 1.0,
#     '48': 2.0,
#     '49': 2.0,
#     '50': 1.0,
#     '52': 2.0,
#     '53': 1.0,
#     '54': 1.0,
#     '56': 1.0,
#     '60': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '71': 3.0,
#     '75': 2.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '84': 1.0,
#     '96': 1.0,
#     '102': 1.0},
#    'passesTotal': {'0': 2.0,
#     '8': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 1.0,
#     '20': 2.0,
#     '24': 1.0,
#     '33': 2.0,
#     '34': 2.0,
#     '35': 1.0,
#     '47': 1.0,
#     '49': 1.0,
#     '50': 1.0,
#     '52': 1.0,
#     '54': 1.0,
#     '56': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '71': 3.0,
#     '75': 2.0,
#     '77': 1.0,
#     '83': 1.0,
#     '102': 1.0,
#     '10': 1.0,
#     '38': 1.0,
#     '39': 1.0,
#     '42': 1.0,
#     '48': 1.0,
#     '53': 1.0,
#     '66': 1.0,
#     '81': 1.0},
#    'passesAccurate': {'0': 2.0,
#     '8': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '18': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '24': 1.0,
#     '33': 2.0,
#     '34': 1.0,
#     '35': 1.0,
#     '47': 1.0,
#     '49': 1.0,
#     '50': 1.0,
#     '52': 1.0,
#     '54': 1.0,
#     '56': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '71': 3.0,
#     '75': 2.0,
#     '77': 1.0,
#     '83': 1.0,
#     '102': 1.0},
#    'passSuccess': {'0': 100.0,
#     '8': 100.0,
#     '12': 100.0,
#     '13': 100.0,
#     '15': 100.0,
#     '18': 100.0,
#     '19': 100.0,
#     '20': 50.0,
#     '24': 100.0,
#     '33': 100.0,
#     '34': 50.0,
#     '35': 100.0,
#     '47': 100.0,
#     '49': 100.0,
#     '50': 100.0,
#     '52': 100.0,
#     '54': 100.0,
#     '56': 100.0,
#     '67': 100.0,
#     '69': 100.0,
#     '71': 100.0,
#     '75': 100.0,
#     '77': 100.0,
#     '83': 100.0,
#     '102': 100.0,
#     '10': 0.0,
#     '38': 0.0,
#     '39': 0.0,
#     '42': 0.0,
#     '48': 0.0,
#     '53': 0.0,
#     '66': 0.0,
#     '81': 0.0},
#    'foulsCommited': {'42': 1.0},
#    'tacklesTotal': {'3': 1.0, '20': 1.0},
#    'tackleSuccessful': {'3': 1.0, '20': 1.0},
#    'tackleSuccess': {'3': 100.0, '20': 100.0},
#    'dribblesWon': {'48': 1.0},
#    'dribblesAttempted': {'48': 1.0},
#    'dribbleSuccess': {'48': 100.0}}},
#  {'playerId': 298659,
#   'shirtNo': 15,
#   'name': 'Harry Toffolo',
#   'position': 'DL',
#   'height': 183,
#   'weight': 71,
#   'age': 28,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'7': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '28': 1.0,
#     '30': 1.0,
#     '33': 1.0,
#     '39': 2.0,
#     '43': 1.0,
#     '48': 2.0,
#     '49': 1.0,
#     '67': 2.0,
#     '69': 1.0,
#     '75': 1.0,
#     '76': 1.0,
#     '78': 2.0,
#     '83': 1.0,
#     '91': 2.0,
#     '97': 1.0},
#    'ratings': {'0': 6.0,
#     '7': 6.02,
#     '10': 6.03,
#     '12': 6.03,
#     '13': 6.03,
#     '15': 6.02,
#     '20': 5.99,
#     '22': 6.04,
#     '28': 6.03,
#     '30': 5.98,
#     '33': 5.97,
#     '39': 5.93,
#     '43': 5.92,
#     '48': 5.94,
#     '49': 5.95,
#     '52': 6.03,
#     '55': 6.16,
#     '67': 6.42,
#     '68': 6.51,
#     '69': 6.5,
#     '75': 6.5,
#     '76': 6.58,
#     '78': 6.58,
#     '83': 6.58,
#     '85': 6.71,
#     '91': 6.77,
#     '97': 6.78,
#     '100': 6.61},
#    'clearances': {'22': 1.0, '55': 1.0, '85': 1.0},
#    'touches': {'4': 1.0,
#     '7': 2.0,
#     '10': 2.0,
#     '12': 2.0,
#     '13': 1.0,
#     '15': 1.0,
#     '16': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '28': 1.0,
#     '30': 1.0,
#     '33': 1.0,
#     '34': 1.0,
#     '39': 2.0,
#     '43': 5.0,
#     '44': 3.0,
#     '48': 2.0,
#     '49': 2.0,
#     '52': 1.0,
#     '55': 2.0,
#     '67': 2.0,
#     '68': 5.0,
#     '69': 1.0,
#     '75': 1.0,
#     '76': 1.0,
#     '78': 2.0,
#     '79': 1.0,
#     '80': 1.0,
#     '83': 1.0,
#     '85': 1.0,
#     '91': 2.0,
#     '97': 1.0,
#     '99': 1.0},
#    'passesTotal': {'7': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '39': 2.0,
#     '48': 2.0,
#     '49': 1.0,
#     '76': 1.0,
#     '78': 2.0,
#     '97': 1.0,
#     '15': 1.0,
#     '30': 1.0,
#     '33': 1.0,
#     '43': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '83': 1.0,
#     '91': 2.0},
#    'passesAccurate': {'7': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '39': 1.0,
#     '48': 2.0,
#     '49': 1.0,
#     '76': 1.0,
#     '78': 1.0,
#     '97': 1.0},
#    'passesKey': {'67': 1.0},
#    'passSuccess': {'7': 100.0,
#     '10': 100.0,
#     '12': 100.0,
#     '13': 100.0,
#     '39': 50.0,
#     '48': 100.0,
#     '49': 100.0,
#     '76': 100.0,
#     '78': 50.0,
#     '97': 100.0,
#     '15': 0.0,
#     '30': 0.0,
#     '33': 0.0,
#     '43': 0.0,
#     '67': 0.0,
#     '69': 0.0,
#     '83': 0.0,
#     '91': 0.0},
#    'aerialsTotal': {'52': 1.0, '76': 1.0, '85': 1.0, '91': 1.0, '30': 1.0},
#    'aerialsWon': {'52': 1.0, '76': 1.0, '85': 1.0, '91': 1.0},
#    'aerialSuccess': {'30': 0.0},
#    'defensiveAerials': {'30': 1.0, '52': 1.0, '76': 1.0, '85': 1.0, '91': 1.0},
#    'throwInsTotal': {'4': 1.0,
#     '7': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '16': 1.0,
#     '34': 1.0,
#     '43': 3.0,
#     '44': 3.0,
#     '49': 1.0,
#     '68': 1.0,
#     '79': 1.0,
#     '80': 1.0},
#    'throwInsAccurate': {'7': 1.0,
#     '10': 1.0,
#     '34': 1.0,
#     '43': 3.0,
#     '44': 2.0,
#     '49': 1.0,
#     '79': 1.0},
#    'foulsCommited': {'30': 1.0, '68': 1.0},
#    'tacklesTotal': {'68': 1.0, '55': 1.0, '39': 1.0},
#    'tackleSuccessful': {'68': 1.0, '55': 1.0},
#    'tackleUnsuccesful': {'39': 1.0},
#    'tackleSuccess': {'68': 100.0, '55': 100.0, '39': 0.0},
#    'dribbledPast': {'39': 1.0},
#    'dispossessed': {'68': 1.0}}},
#  {'playerId': 334653,
#   'shirtNo': 16,
#   'name': 'Nicolás Domínguez',
#   'position': 'DMC',
#   'height': 179,
#   'weight': 73,
#   'age': 25,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 399250,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 80,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 1.0,
#     '1': 1.0,
#     '4': 1.0,
#     '7': 2.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '20': 1.0,
#     '30': 4.0,
#     '34': 2.0,
#     '36': 1.0,
#     '38': 2.0,
#     '43': 1.0,
#     '45': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '49': 1.0,
#     '67': 1.0,
#     '71': 1.0,
#     '72': 1.0,
#     '74': 2.0,
#     '75': 1.0,
#     '78': 2.0,
#     '79': 2.0},
#    'ratings': {'0': 6.0,
#     '1': 6.01,
#     '4': 6.01,
#     '7': 6.01,
#     '10': 5.98,
#     '12': 5.98,
#     '13': 6.07,
#     '16': 6.04,
#     '20': 6.03,
#     '27': 6.08,
#     '28': 6.18,
#     '30': 6.24,
#     '31': 6.38,
#     '34': 6.47,
#     '36': 6.47,
#     '38': 6.47,
#     '39': 6.71,
#     '43': 6.71,
#     '44': 6.68,
#     '45': 6.81,
#     '47': 6.81,
#     '48': 6.82,
#     '49': 6.82,
#     '51': 7.02,
#     '53': 6.99,
#     '63': 7.07,
#     '67': 7.08,
#     '68': 7.16,
#     '71': 7.17,
#     '72': 7.16,
#     '74': 7.16,
#     '75': 7.15,
#     '78': 7.25,
#     '79': 7.24,
#     '80': 7.44},
#    'shotsTotal': {'44': 1.0, '48': 1.0},
#    'shotsOffTarget': {'44': 1.0},
#    'shotsBlocked': {'48': 1.0},
#    'clearances': {'27': 1.0},
#    'interceptions': {'28': 1.0, '31': 1.0, '39': 1.0, '51': 1.0},
#    'touches': {'0': 1.0,
#     '1': 1.0,
#     '4': 1.0,
#     '7': 2.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '20': 1.0,
#     '23': 1.0,
#     '27': 1.0,
#     '28': 1.0,
#     '30': 5.0,
#     '31': 2.0,
#     '34': 2.0,
#     '36': 1.0,
#     '38': 2.0,
#     '39': 2.0,
#     '43': 1.0,
#     '44': 1.0,
#     '45': 2.0,
#     '47': 1.0,
#     '48': 3.0,
#     '49': 1.0,
#     '51': 1.0,
#     '63': 1.0,
#     '67': 1.0,
#     '68': 1.0,
#     '71': 1.0,
#     '72': 1.0,
#     '74': 3.0,
#     '75': 1.0,
#     '78': 2.0,
#     '79': 2.0},
#    'passesTotal': {'0': 1.0,
#     '1': 1.0,
#     '4': 1.0,
#     '7': 2.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '30': 4.0,
#     '34': 2.0,
#     '36': 1.0,
#     '38': 2.0,
#     '43': 1.0,
#     '45': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '49': 1.0,
#     '67': 1.0,
#     '71': 1.0,
#     '72': 1.0,
#     '74': 2.0,
#     '78': 2.0,
#     '79': 2.0,
#     '20': 1.0,
#     '75': 1.0},
#    'passesAccurate': {'0': 1.0,
#     '1': 1.0,
#     '4': 1.0,
#     '7': 1.0,
#     '10': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '30': 2.0,
#     '34': 2.0,
#     '36': 1.0,
#     '38': 2.0,
#     '43': 1.0,
#     '45': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '49': 1.0,
#     '67': 1.0,
#     '71': 1.0,
#     '72': 1.0,
#     '74': 2.0,
#     '78': 2.0,
#     '79': 1.0},
#    'passesKey': {'13': 1.0},
#    'passSuccess': {'0': 100.0,
#     '1': 100.0,
#     '4': 100.0,
#     '7': 50.0,
#     '10': 100.0,
#     '12': 100.0,
#     '13': 100.0,
#     '30': 50.0,
#     '34': 100.0,
#     '36': 100.0,
#     '38': 100.0,
#     '43': 100.0,
#     '45': 100.0,
#     '47': 100.0,
#     '48': 100.0,
#     '49': 100.0,
#     '67': 100.0,
#     '71': 100.0,
#     '72': 100.0,
#     '74': 100.0,
#     '78': 100.0,
#     '79': 50.0,
#     '20': 0.0,
#     '75': 0.0},
#    'aerialsTotal': {'34': 1.0, '78': 1.0, '16': 1.0},
#    'aerialsWon': {'34': 1.0, '78': 1.0},
#    'aerialSuccess': {'16': 0.0},
#    'offensiveAerials': {'78': 1.0},
#    'defensiveAerials': {'16': 1.0, '34': 1.0},
#    'foulsCommited': {'16': 1.0, '72': 1.0},
#    'tacklesTotal': {'39': 1.0,
#     '45': 1.0,
#     '30': 1.0,
#     '68': 1.0,
#     '10': 1.0,
#     '53': 1.0},
#    'tackleSuccessful': {'39': 1.0, '45': 1.0, '30': 1.0, '68': 1.0},
#    'tackleUnsuccesful': {'10': 1.0, '53': 1.0},
#    'tackleSuccess': {'39': 100.0,
#     '45': 100.0,
#     '30': 100.0,
#     '68': 100.0,
#     '10': 0.0,
#     '53': 0.0},
#    'dribbledPast': {'10': 1.0, '53': 1.0}}},
#  {'playerId': 342830,
#   'shirtNo': 22,
#   'name': 'Ryan Yates',
#   'position': 'DMC',
#   'height': 190,
#   'weight': 87,
#   'age': 26,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 1.0,
#     '12': 2.0,
#     '20': 1.0,
#     '22': 1.0,
#     '30': 2.0,
#     '31': 1.0,
#     '34': 1.0,
#     '36': 2.0,
#     '38': 2.0,
#     '48': 2.0,
#     '50': 2.0,
#     '56': 1.0,
#     '57': 2.0,
#     '66': 1.0,
#     '67': 1.0,
#     '72': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '81': 1.0,
#     '93': 1.0,
#     '98': 1.0,
#     '102': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 5.98,
#     '5': 5.97,
#     '12': 5.96,
#     '19': 6.0,
#     '20': 6.0,
#     '21': 6.1,
#     '22': 6.09,
#     '30': 6.1,
#     '31': 6.09,
#     '34': 6.08,
#     '35': 6.16,
#     '36': 6.14,
#     '38': 6.11,
#     '41': 6.1,
#     '45': 6.08,
#     '48': 6.09,
#     '50': 6.08,
#     '56': 6.08,
#     '57': 6.07,
#     '58': 6.16,
#     '66': 6.16,
#     '67': 6.17,
#     '72': 6.17,
#     '73': 6.22,
#     '74': 6.19,
#     '78': 6.27,
#     '79': 6.28,
#     '81': 6.28,
#     '83': 6.38,
#     '91': 6.46,
#     '92': 6.5,
#     '93': 6.49,
#     '98': 6.56,
#     '100': 6.41,
#     '102': 6.41},
#    'clearances': {'73': 1.0},
#    'interceptions': {'21': 1.0, '83': 1.0},
#    'touches': {'0': 1.0,
#     '12': 2.0,
#     '13': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '21': 1.0,
#     '22': 1.0,
#     '30': 2.0,
#     '31': 1.0,
#     '34': 1.0,
#     '36': 2.0,
#     '38': 3.0,
#     '41': 1.0,
#     '48': 2.0,
#     '50': 2.0,
#     '56': 1.0,
#     '57': 2.0,
#     '58': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '72': 1.0,
#     '73': 1.0,
#     '74': 2.0,
#     '78': 1.0,
#     '79': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '91': 1.0,
#     '92': 1.0,
#     '93': 1.0,
#     '98': 1.0,
#     '102': 1.0},
#    'passesTotal': {'0': 1.0,
#     '12': 2.0,
#     '20': 1.0,
#     '30': 2.0,
#     '38': 2.0,
#     '48': 2.0,
#     '50': 2.0,
#     '56': 1.0,
#     '57': 2.0,
#     '66': 1.0,
#     '67': 1.0,
#     '72': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '81': 1.0,
#     '102': 1.0,
#     '22': 1.0,
#     '31': 1.0,
#     '34': 1.0,
#     '36': 2.0,
#     '93': 1.0,
#     '98': 1.0},
#    'passesAccurate': {'0': 1.0,
#     '12': 1.0,
#     '20': 1.0,
#     '30': 2.0,
#     '38': 2.0,
#     '48': 2.0,
#     '50': 2.0,
#     '56': 1.0,
#     '57': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '72': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '81': 1.0,
#     '102': 1.0},
#    'passSuccess': {'0': 100.0,
#     '12': 50.0,
#     '20': 100.0,
#     '30': 100.0,
#     '38': 100.0,
#     '48': 100.0,
#     '50': 100.0,
#     '56': 100.0,
#     '57': 50.0,
#     '66': 100.0,
#     '67': 100.0,
#     '72': 100.0,
#     '78': 100.0,
#     '79': 100.0,
#     '81': 100.0,
#     '102': 100.0,
#     '22': 0.0,
#     '31': 0.0,
#     '34': 0.0,
#     '36': 0.0,
#     '93': 0.0,
#     '98': 0.0},
#    'aerialsTotal': {'35': 1.0, '78': 1.0, '98': 1.0},
#    'aerialsWon': {'35': 1.0, '78': 1.0, '98': 1.0},
#    'offensiveAerials': {'35': 1.0, '78': 1.0},
#    'defensiveAerials': {'98': 1.0},
#    'foulsCommited': {'1': 1.0, '5': 1.0, '45': 1.0, '50': 1.0},
#    'dribblesAttempted': {'41': 1.0},
#    'dribblesLost': {'41': 1.0},
#    'dispossessed': {'74': 1.0}}},
#  {'playerId': 124688,
#   'shirtNo': 27,
#   'name': 'Divock Origi',
#   'position': 'AMR',
#   'height': 185,
#   'weight': 75,
#   'age': 28,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 281049,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 66,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'3': 1.0,
#     '6': 1.0,
#     '13': 1.0,
#     '19': 1.0,
#     '22': 1.0,
#     '31': 1.0,
#     '40': 1.0,
#     '41': 1.0,
#     '47': 3.0,
#     '49': 1.0,
#     '50': 1.0,
#     '56': 1.0,
#     '60': 2.0},
#    'ratings': {'0': 6.0,
#     '1': 5.95,
#     '3': 5.94,
#     '6': 5.94,
#     '11': 5.92,
#     '13': 5.91,
#     '14': 5.96,
#     '18': 5.91,
#     '19': 5.92,
#     '21': 6.0,
#     '22': 6.19,
#     '31': 6.18,
#     '32': 6.26,
#     '35': 6.25,
#     '40': 6.25,
#     '41': 6.25,
#     '44': 6.23,
#     '47': 6.22,
#     '49': 6.21,
#     '50': 6.22,
#     '53': 6.2,
#     '56': 6.2,
#     '57': 6.19,
#     '58': 6.33,
#     '60': 6.28,
#     '66': 6.37},
#    'shotsTotal': {'14': 1.0},
#    'shotsOffTarget': {'14': 1.0},
#    'touches': {'1': 1.0,
#     '3': 1.0,
#     '6': 1.0,
#     '13': 1.0,
#     '14': 1.0,
#     '18': 1.0,
#     '19': 1.0,
#     '21': 1.0,
#     '22': 1.0,
#     '31': 2.0,
#     '32': 1.0,
#     '35': 1.0,
#     '36': 1.0,
#     '40': 1.0,
#     '41': 1.0,
#     '47': 3.0,
#     '49': 1.0,
#     '50': 1.0,
#     '56': 1.0,
#     '57': 2.0,
#     '58': 1.0,
#     '60': 2.0},
#    'passesTotal': {'19': 1.0,
#     '22': 1.0,
#     '31': 1.0,
#     '40': 1.0,
#     '47': 3.0,
#     '50': 1.0,
#     '56': 1.0,
#     '3': 1.0,
#     '6': 1.0,
#     '13': 1.0,
#     '41': 1.0,
#     '49': 1.0,
#     '60': 2.0},
#    'passesAccurate': {'19': 1.0,
#     '22': 1.0,
#     '31': 1.0,
#     '40': 1.0,
#     '47': 1.0,
#     '50': 1.0,
#     '56': 1.0},
#    'passesKey': {'22': 1.0},
#    'passSuccess': {'19': 100.0,
#     '22': 100.0,
#     '31': 100.0,
#     '40': 100.0,
#     '47': 33.33,
#     '50': 100.0,
#     '56': 100.0,
#     '3': 0.0,
#     '6': 0.0,
#     '13': 0.0,
#     '41': 0.0,
#     '49': 0.0,
#     '60': 0.0},
#    'aerialsTotal': {'32': 1.0,
#     '1': 1.0,
#     '11': 1.0,
#     '44': 1.0,
#     '53': 1.0,
#     '60': 1.0},
#    'aerialsWon': {'32': 1.0},
#    'aerialSuccess': {'1': 0.0, '11': 0.0, '44': 0.0, '53': 0.0, '60': 0.0},
#    'offensiveAerials': {'1': 1.0, '44': 1.0, '53': 1.0},
#    'defensiveAerials': {'11': 1.0, '32': 1.0, '60': 1.0},
#    'foulsCommited': {'18': 1.0},
#    'tacklesTotal': {'58': 1.0, '21': 1.0},
#    'tackleSuccessful': {'58': 1.0, '21': 1.0},
#    'tackleSuccess': {'58': 100.0, '21': 100.0},
#    'dribblesAttempted': {'31': 1.0, '35': 1.0, '57': 1.0},
#    'dribblesLost': {'31': 1.0, '35': 1.0, '57': 1.0}}},
#  {'playerId': 332867,
#   'shirtNo': 10,
#   'name': 'Morgan Gibbs-White',
#   'position': 'AMC',
#   'height': 171,
#   'weight': 0,
#   'age': 24,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 2.0,
#     '9': 1.0,
#     '11': 1.0,
#     '12': 1.0,
#     '19': 1.0,
#     '25': 1.0,
#     '28': 1.0,
#     '33': 3.0,
#     '34': 1.0,
#     '35': 1.0,
#     '38': 1.0,
#     '43': 2.0,
#     '47': 1.0,
#     '48': 1.0,
#     '53': 2.0,
#     '64': 1.0,
#     '66': 1.0,
#     '72': 2.0,
#     '76': 1.0,
#     '77': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '94': 1.0,
#     '98': 1.0,
#     '102': 1.0},
#    'ratings': {'0': 5.99,
#     '9': 6.09,
#     '10': 6.27,
#     '11': 6.26,
#     '12': 6.26,
#     '19': 6.26,
#     '25': 6.26,
#     '28': 6.26,
#     '30': 6.24,
#     '32': 6.28,
#     '33': 6.28,
#     '34': 6.27,
#     '35': 6.26,
#     '38': 6.27,
#     '43': 6.26,
#     '44': 6.23,
#     '47': 6.22,
#     '48': 6.47,
#     '51': 6.52,
#     '52': 6.55,
#     '53': 6.56,
#     '56': 6.52,
#     '64': 6.51,
#     '66': 6.51,
#     '72': 6.51,
#     '76': 6.51,
#     '77': 6.51,
#     '78': 6.52,
#     '79': 6.48,
#     '81': 6.5,
#     '93': 6.48,
#     '94': 6.39,
#     '98': 6.38,
#     '100': 6.36,
#     '102': 6.36},
#    'shotsTotal': {'97': 1.0},
#    'shotsBlocked': {'97': 1.0},
#    'clearances': {'51': 1.0},
#    'interceptions': {'9': 1.0},
#    'touches': {'0': 2.0,
#     '9': 2.0,
#     '10': 3.0,
#     '11': 1.0,
#     '12': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '21': 1.0,
#     '25': 1.0,
#     '28': 1.0,
#     '31': 1.0,
#     '32': 1.0,
#     '33': 3.0,
#     '34': 1.0,
#     '35': 1.0,
#     '38': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '47': 1.0,
#     '48': 2.0,
#     '51': 1.0,
#     '52': 1.0,
#     '53': 3.0,
#     '56': 2.0,
#     '64': 1.0,
#     '66': 1.0,
#     '72': 2.0,
#     '76': 1.0,
#     '77': 2.0,
#     '78': 1.0,
#     '79': 3.0,
#     '81': 1.0,
#     '94': 1.0,
#     '97': 2.0,
#     '98': 1.0,
#     '100': 1.0,
#     '102': 1.0},
#    'passesTotal': {'0': 1.0,
#     '12': 1.0,
#     '19': 1.0,
#     '28': 1.0,
#     '33': 3.0,
#     '38': 1.0,
#     '43': 2.0,
#     '47': 1.0,
#     '48': 1.0,
#     '53': 2.0,
#     '66': 1.0,
#     '72': 2.0,
#     '76': 1.0,
#     '77': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '94': 1.0,
#     '102': 1.0,
#     '9': 1.0,
#     '11': 1.0,
#     '25': 1.0,
#     '34': 1.0,
#     '35': 1.0,
#     '64': 1.0},
#    'passesAccurate': {'0': 1.0,
#     '12': 1.0,
#     '19': 1.0,
#     '28': 1.0,
#     '33': 3.0,
#     '38': 1.0,
#     '43': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '53': 2.0,
#     '66': 1.0,
#     '72': 1.0,
#     '76': 1.0,
#     '77': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '94': 1.0,
#     '102': 1.0},
#    'passesKey': {'48': 1.0},
#    'passSuccess': {'0': 100.0,
#     '12': 100.0,
#     '19': 100.0,
#     '28': 100.0,
#     '33': 100.0,
#     '38': 100.0,
#     '43': 50.0,
#     '47': 100.0,
#     '48': 100.0,
#     '53': 100.0,
#     '66': 100.0,
#     '72': 50.0,
#     '76': 100.0,
#     '77': 100.0,
#     '78': 100.0,
#     '79': 100.0,
#     '94': 100.0,
#     '102': 100.0,
#     '9': 0.0,
#     '11': 0.0,
#     '25': 0.0,
#     '34': 0.0,
#     '35': 0.0,
#     '64': 0.0},
#    'aerialsTotal': {'30': 1.0, '47': 1.0, '81': 1.0, '93': 1.0},
#    'offensiveAerials': {'47': 1.0, '81': 1.0, '93': 1.0},
#    'defensiveAerials': {'30': 1.0},
#    'cornersTotal': {'97': 1.0},
#    'cornersAccurate': {'94': 1.0},
#    'throwInAccuracy': {'97': 0.0},
#    'dribblesWon': {'10': 1.0, '48': 1.0},
#    'dribblesAttempted': {'10': 2.0, '48': 1.0},
#    'dribblesLost': {'10': 1.0},
#    'dribbleSuccess': {'10': 50.0, '48': 100.0},
#    'dispossessed': {'44': 1.0, '56': 1.0}}},
#  {'playerId': 350088,
#   'shirtNo': 14,
#   'name': 'Callum Hudson-Odoi',
#   'position': 'AML',
#   'height': 182,
#   'weight': 76,
#   'age': 23,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'3': 1.0,
#     '4': 1.0,
#     '7': 1.0,
#     '13': 1.0,
#     '22': 1.0,
#     '28': 1.0,
#     '38': 1.0,
#     '41': 1.0,
#     '45': 1.0,
#     '48': 4.0,
#     '49': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '94': 1.0,
#     '97': 1.0,
#     '102': 1.0},
#    'ratings': {'0': 6.0,
#     '3': 5.99,
#     '4': 5.99,
#     '7': 5.99,
#     '12': 5.96,
#     '13': 5.96,
#     '22': 6.07,
#     '28': 6.05,
#     '30': 6.02,
#     '32': 6.0,
#     '33': 5.99,
#     '35': 5.95,
#     '36': 5.96,
#     '38': 5.96,
#     '40': 5.97,
#     '41': 5.96,
#     '45': 6.13,
#     '48': 6.14,
#     '49': 6.49,
#     '54': 6.45,
#     '66': 6.44,
#     '67': 6.44,
#     '69': 6.45,
#     '72': 6.45,
#     '74': 6.45,
#     '77': 6.61,
#     '78': 6.59,
#     '81': 6.6,
#     '82': 6.94,
#     '83': 6.94,
#     '84': 7.02,
#     '91': 7.07,
#     '94': 7.06,
#     '97': 7.32,
#     '100': 7.22,
#     '102': 7.21},
#    'shotsTotal': {'82': 1.0},
#    'shotsOnTarget': {'82': 1.0},
#    'clearances': {'91': 1.0},
#    'interceptions': {'22': 1.0},
#    'touches': {'3': 1.0,
#     '4': 1.0,
#     '7': 1.0,
#     '12': 1.0,
#     '13': 1.0,
#     '22': 2.0,
#     '28': 2.0,
#     '30': 2.0,
#     '32': 1.0,
#     '33': 1.0,
#     '35': 1.0,
#     '36': 1.0,
#     '38': 1.0,
#     '41': 1.0,
#     '45': 2.0,
#     '48': 4.0,
#     '49': 3.0,
#     '54': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '74': 3.0,
#     '77': 2.0,
#     '78': 1.0,
#     '81': 1.0,
#     '82': 2.0,
#     '83': 1.0,
#     '84': 1.0,
#     '91': 1.0,
#     '94': 1.0,
#     '97': 2.0,
#     '100': 1.0,
#     '102': 1.0},
#    'passesTotal': {'7': 1.0,
#     '13': 1.0,
#     '22': 1.0,
#     '28': 1.0,
#     '38': 1.0,
#     '48': 4.0,
#     '49': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '97': 1.0,
#     '3': 1.0,
#     '4': 1.0,
#     '41': 1.0,
#     '45': 1.0,
#     '102': 1.0},
#    'passesAccurate': {'7': 1.0,
#     '13': 1.0,
#     '22': 1.0,
#     '28': 1.0,
#     '38': 1.0,
#     '48': 4.0,
#     '49': 1.0,
#     '67': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '97': 1.0},
#    'passesKey': {'97': 1.0},
#    'passSuccess': {'7': 100.0,
#     '13': 100.0,
#     '22': 100.0,
#     '28': 100.0,
#     '38': 100.0,
#     '48': 100.0,
#     '49': 100.0,
#     '67': 100.0,
#     '69': 100.0,
#     '72': 100.0,
#     '81': 100.0,
#     '83': 100.0,
#     '97': 100.0,
#     '3': 0.0,
#     '4': 0.0,
#     '41': 0.0,
#     '45': 0.0,
#     '102': 0.0},
#    'dribblesWon': {'45': 1.0, '49': 2.0, '77': 1.0, '82': 1.0, '97': 1.0},
#    'dribblesAttempted': {'45': 1.0,
#     '49': 2.0,
#     '77': 1.0,
#     '82': 1.0,
#     '97': 1.0,
#     '28': 1.0,
#     '32': 1.0,
#     '33': 1.0,
#     '66': 1.0,
#     '78': 1.0},
#    'dribblesLost': {'28': 1.0, '32': 1.0, '33': 1.0, '66': 1.0, '78': 1.0},
#    'dribbleSuccess': {'45': 100.0,
#     '49': 100.0,
#     '77': 100.0,
#     '82': 100.0,
#     '97': 100.0,
#     '28': 0.0,
#     '32': 0.0,
#     '33': 0.0,
#     '66': 0.0,
#     '78': 0.0},
#    'dispossessed': {'12': 1.0}}},
#  {'playerId': 413211,
#   'shirtNo': 21,
#   'name': 'Anthony Elanga',
#   'position': 'FW',
#   'height': 178,
#   'weight': 70,
#   'age': 21,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'7': 1.0,
#     '20': 1.0,
#     '28': 1.0,
#     '40': 1.0,
#     '44': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '71': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '81': 2.0,
#     '102': 1.0},
#    'ratings': {'0': 6.0,
#     '7': 5.98,
#     '9': 5.94,
#     '20': 5.95,
#     '22': 5.99,
#     '27': 6.04,
#     '28': 6.04,
#     '30': 6.03,
#     '31': 6.01,
#     '36': 5.99,
#     '40': 6.0,
#     '43': 5.96,
#     '44': 5.96,
#     '59': 6.01,
#     '66': 6.02,
#     '67': 5.92,
#     '70': 5.9,
#     '71': 5.89,
#     '73': 5.9,
#     '76': 5.9,
#     '81': 5.9,
#     '85': 5.95,
#     '100': 5.88,
#     '102': 5.89},
#    'shotsTotal': {'22': 1.0, '67': 1.0},
#    'shotsOnTarget': {'22': 1.0},
#    'shotsOffTarget': {'67': 1.0},
#    'clearances': {'27': 1.0, '59': 1.0, '85': 1.0},
#    'touches': {'7': 2.0,
#     '20': 1.0,
#     '22': 1.0,
#     '27': 1.0,
#     '28': 1.0,
#     '40': 1.0,
#     '43': 1.0,
#     '44': 1.0,
#     '59': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '70': 2.0,
#     '71': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '81': 2.0,
#     '85': 1.0,
#     '90': 1.0,
#     '102': 1.0},
#    'passesTotal': {'20': 1.0,
#     '28': 1.0,
#     '40': 1.0,
#     '66': 1.0,
#     '73': 1.0,
#     '81': 2.0,
#     '102': 1.0,
#     '7': 1.0,
#     '44': 1.0,
#     '70': 1.0,
#     '76': 1.0},
#    'passesAccurate': {'20': 1.0,
#     '28': 1.0,
#     '40': 1.0,
#     '66': 1.0,
#     '73': 1.0,
#     '81': 2.0,
#     '102': 1.0},
#    'passSuccess': {'20': 100.0,
#     '28': 100.0,
#     '40': 100.0,
#     '66': 100.0,
#     '73': 100.0,
#     '81': 100.0,
#     '102': 100.0,
#     '7': 0.0,
#     '44': 0.0,
#     '70': 0.0,
#     '76': 0.0},
#    'aerialsTotal': {'30': 1.0},
#    'defensiveAerials': {'30': 1.0},
#    'offsidesCaught': {'31': 1.0, '36': 1.0},
#    'tacklesTotal': {'9': 1.0},
#    'tackleUnsuccesful': {'9': 1.0},
#    'dribbledPast': {'9': 1.0},
#    'dribblesAttempted': {'7': 1.0},
#    'dribblesLost': {'7': 1.0},
#    'dispossessed': {'43': 1.0}}},
#  {'playerId': 281049,
#   'shirtNo': 9,
#   'name': 'Taiwo Awoniyi',
#   'position': 'Sub',
#   'height': 183,
#   'weight': 84,
#   'age': 26,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 66,
#   'subbedOutPlayerId': 124688,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'67': 1.0, '76': 1.0, '78': 1.0, '79': 1.0},
#    'ratings': {'66': 6.0,
#     '67': 6.0,
#     '69': 5.97,
#     '70': 5.95,
#     '76': 5.96,
#     '77': 5.97,
#     '78': 5.97,
#     '79': 5.97,
#     '82': 6.01,
#     '93': 6.14,
#     '96': 6.13,
#     '100': 6.02},
#    'shotsTotal': {'93': 1.0},
#    'shotsBlocked': {'93': 1.0},
#    'touches': {'67': 1.0,
#     '69': 1.0,
#     '70': 1.0,
#     '76': 1.0,
#     '77': 3.0,
#     '78': 2.0,
#     '79': 1.0,
#     '82': 1.0,
#     '93': 2.0,
#     '100': 2.0},
#    'passesTotal': {'67': 1.0, '76': 1.0, '79': 1.0, '78': 1.0},
#    'passesAccurate': {'67': 1.0, '76': 1.0, '79': 1.0},
#    'passSuccess': {'67': 100.0, '76': 100.0, '79': 100.0, '78': 0.0},
#    'aerialsTotal': {'77': 1.0, '70': 1.0, '96': 1.0},
#    'aerialsWon': {'77': 1.0},
#    'aerialSuccess': {'70': 0.0, '96': 0.0},
#    'offensiveAerials': {'70': 1.0, '77': 1.0},
#    'defensiveAerials': {'96': 1.0},
#    'cornersTotal': {'93': 1.0},
#    'tacklesTotal': {'93': 1.0},
#    'tackleSuccessful': {'93': 1.0},
#    'tackleSuccess': {'93': 100.0},
#    'dribblesAttempted': {'100': 1.0},
#    'dribblesLost': {'100': 1.0}}},
#  {'playerId': 399250,
#   'shirtNo': 28,
#   'name': 'Danilo',
#   'position': 'Sub',
#   'height': 176,
#   'weight': 69,
#   'age': 22,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 80,
#   'subbedOutPlayerId': 334653,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'81': 1.0, '97': 1.0},
#    'ratings': {'80': 6.0,
#     '81': 6.22,
#     '83': 6.35,
#     '94': 6.24,
#     '97': 6.24,
#     '100': 6.14},
#    'touches': {'81': 2.0, '83': 1.0, '97': 1.0},
#    'passesTotal': {'81': 1.0, '97': 1.0},
#    'passesAccurate': {'81': 1.0, '97': 1.0},
#    'passesKey': {'81': 1.0},
#    'passSuccess': {'81': 100.0, '97': 100.0},
#    'foulsCommited': {'94': 1.0},
#    'tacklesTotal': {'81': 1.0, '83': 1.0},
#    'tackleSuccessful': {'81': 1.0, '83': 1.0},
#    'tackleSuccess': {'81': 100.0, '83': 100.0}}},
#  {'playerId': 102173,
#   'shirtNo': 18,
#   'name': 'Felipe',
#   'position': 'Sub',
#   'height': 190,
#   'weight': 83,
#   'age': 34,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 434076,
#   'shirtNo': 37,
#   'name': 'Rodrigo Ribeiro',
#   'position': 'Sub',
#   'height': 185,
#   'weight': 75,
#   'age': 18,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 296319,
#   'shirtNo': 19,
#   'name': 'Moussa Niakhaté',
#   'position': 'Sub',
#   'height': 190,
#   'weight': 82,
#   'age': 28,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 66741,
#   'shirtNo': 8,
#   'name': 'Cheikhou Kouyaté',
#   'position': 'Sub',
#   'height': 189,
#   'weight': 83,
#   'age': 34,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 319712,
#   'shirtNo': 1,
#   'name': 'Matt Turner',
#   'position': 'Sub',
#   'height': 191,
#   'weight': 84,
#   'age': 29,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 328075,
#   'shirtNo': 6,
#   'name': 'Ibrahim Sangaré',
#   'position': 'Sub',
#   'height': 191,
#   'weight': 77,
#   'age': 26,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 513614,
#   'shirtNo': 53,
#   'name': 'Joe Gardner',
#   'position': 'Sub',
#   'height': 0,
#   'weight': 0,
#   'age': 18,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 322176,
#   'shirtNo': 62,
#   'name': 'Caoimhín Kelleher',
#   'position': 'GK',
#   'height': 188,
#   'weight': 74,
#   'age': 25,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'totalSaves': {'22': 1.0, '82': 1.0},
#    'collected': {'82': 1.0},
#    'parriedSafe': {'22': 1.0},
#    'possession': {'1': 2.0,
#     '2': 1.0,
#     '3': 1.0,
#     '4': 1.0,
#     '6': 3.0,
#     '7': 1.0,
#     '8': 1.0,
#     '11': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '18': 1.0,
#     '20': 1.0,
#     '28': 1.0,
#     '32': 1.0,
#     '34': 1.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 2.0,
#     '40': 1.0,
#     '41': 1.0,
#     '42': 1.0,
#     '44': 1.0,
#     '45': 1.0,
#     '49': 1.0,
#     '54': 1.0,
#     '56': 2.0,
#     '62': 1.0,
#     '63': 1.0,
#     '64': 1.0,
#     '67': 2.0,
#     '69': 1.0,
#     '76': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '82': 2.0,
#     '90': 1.0,
#     '91': 1.0,
#     '93': 1.0,
#     '96': 1.0,
#     '98': 1.0,
#     '99': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 6.0,
#     '2': 6.0,
#     '3': 6.01,
#     '4': 6.01,
#     '6': 6.01,
#     '7': 6.0,
#     '8': 6.0,
#     '11': 6.0,
#     '13': 5.99,
#     '14': 6.0,
#     '18': 6.0,
#     '20': 6.0,
#     '22': 6.2,
#     '28': 6.21,
#     '32': 6.21,
#     '34': 6.22,
#     '37': 6.22,
#     '38': 6.22,
#     '39': 6.22,
#     '40': 6.23,
#     '41': 6.22,
#     '42': 6.22,
#     '44': 6.23,
#     '45': 6.23,
#     '49': 6.24,
#     '54': 6.24,
#     '56': 6.25,
#     '62': 6.25,
#     '63': 6.25,
#     '64': 6.25,
#     '67': 6.25,
#     '69': 6.27,
#     '76': 6.28,
#     '78': 6.26,
#     '79': 6.27,
#     '82': 6.64,
#     '90': 6.65,
#     '91': 6.64,
#     '93': 6.63,
#     '96': 6.63,
#     '98': 6.63,
#     '99': 6.64,
#     '100': 6.69,
#     '102': 7.02},
#    'touches': {'1': 2.0,
#     '2': 1.0,
#     '3': 1.0,
#     '4': 1.0,
#     '6': 3.0,
#     '7': 1.0,
#     '8': 1.0,
#     '11': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '18': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '28': 1.0,
#     '32': 1.0,
#     '34': 1.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 2.0,
#     '40': 1.0,
#     '41': 1.0,
#     '42': 1.0,
#     '44': 1.0,
#     '45': 1.0,
#     '49': 1.0,
#     '54': 1.0,
#     '56': 2.0,
#     '62': 1.0,
#     '63': 1.0,
#     '64': 1.0,
#     '67': 2.0,
#     '69': 1.0,
#     '76': 1.0,
#     '78': 1.0,
#     '79': 1.0,
#     '82': 3.0,
#     '90': 1.0,
#     '91': 1.0,
#     '93': 1.0,
#     '96': 1.0,
#     '98': 1.0,
#     '99': 1.0},
#    'passesTotal': {'1': 2.0,
#     '2': 1.0,
#     '3': 1.0,
#     '4': 1.0,
#     '6': 3.0,
#     '8': 1.0,
#     '14': 2.0,
#     '18': 1.0,
#     '20': 1.0,
#     '32': 1.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 2.0,
#     '40': 1.0,
#     '42': 1.0,
#     '44': 1.0,
#     '45': 1.0,
#     '54': 1.0,
#     '56': 2.0,
#     '62': 1.0,
#     '63': 1.0,
#     '64': 1.0,
#     '67': 2.0,
#     '69': 1.0,
#     '82': 1.0,
#     '90': 1.0,
#     '99': 1.0,
#     '7': 1.0,
#     '13': 1.0,
#     '41': 1.0,
#     '78': 1.0,
#     '91': 1.0,
#     '93': 1.0,
#     '98': 1.0},
#    'passesAccurate': {'1': 2.0,
#     '2': 1.0,
#     '3': 1.0,
#     '4': 1.0,
#     '6': 3.0,
#     '8': 1.0,
#     '14': 2.0,
#     '18': 1.0,
#     '20': 1.0,
#     '32': 1.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 2.0,
#     '40': 1.0,
#     '42': 1.0,
#     '44': 1.0,
#     '45': 1.0,
#     '54': 1.0,
#     '56': 2.0,
#     '62': 1.0,
#     '63': 1.0,
#     '64': 1.0,
#     '67': 2.0,
#     '69': 1.0,
#     '82': 1.0,
#     '90': 1.0,
#     '99': 1.0},
#    'passSuccess': {'1': 100.0,
#     '2': 100.0,
#     '3': 100.0,
#     '4': 100.0,
#     '6': 100.0,
#     '8': 100.0,
#     '14': 100.0,
#     '18': 100.0,
#     '20': 100.0,
#     '32': 100.0,
#     '37': 100.0,
#     '38': 100.0,
#     '39': 100.0,
#     '40': 100.0,
#     '42': 100.0,
#     '44': 100.0,
#     '45': 100.0,
#     '54': 100.0,
#     '56': 100.0,
#     '62': 100.0,
#     '63': 100.0,
#     '64': 100.0,
#     '67': 100.0,
#     '69': 100.0,
#     '82': 100.0,
#     '90': 100.0,
#     '99': 100.0,
#     '7': 0.0,
#     '13': 0.0,
#     '41': 0.0,
#     '78': 0.0,
#     '91': 0.0,
#     '93': 0.0,
#     '98': 0.0}}},
#  {'playerId': 424945,
#   'shirtNo': 84,
#   'name': 'Conor Bradley',
#   'position': 'DR',
#   'height': 180,
#   'weight': 64,
#   'age': 20,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 301455,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 85,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'4': 2.0,
#     '7': 2.0,
#     '9': 1.0,
#     '13': 1.0,
#     '16': 1.0,
#     '18': 1.0,
#     '21': 6.0,
#     '23': 1.0,
#     '24': 1.0,
#     '25': 1.0,
#     '26': 2.0,
#     '28': 1.0,
#     '29': 1.0,
#     '30': 1.0,
#     '34': 2.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 1.0,
#     '40': 1.0,
#     '42': 1.0,
#     '45': 1.0,
#     '51': 1.0,
#     '53': 1.0,
#     '54': 1.0,
#     '55': 3.0,
#     '58': 2.0,
#     '64': 1.0,
#     '66': 2.0,
#     '68': 1.0,
#     '72': 1.0,
#     '73': 2.0,
#     '74': 1.0,
#     '76': 3.0,
#     '81': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 1.0},
#    'ratings': {'0': 6.0,
#     '4': 5.99,
#     '7': 6.09,
#     '9': 6.09,
#     '13': 6.09,
#     '16': 6.1,
#     '18': 6.1,
#     '20': 6.08,
#     '21': 6.09,
#     '23': 6.1,
#     '24': 6.1,
#     '25': 6.09,
#     '26': 6.26,
#     '28': 6.35,
#     '29': 6.35,
#     '30': 6.45,
#     '32': 6.55,
#     '33': 6.68,
#     '34': 6.68,
#     '37': 6.68,
#     '38': 6.68,
#     '39': 6.83,
#     '40': 6.82,
#     '42': 6.82,
#     '44': 6.95,
#     '45': 6.95,
#     '49': 6.89,
#     '51': 6.88,
#     '53': 7.05,
#     '54': 7.06,
#     '55': 7.06,
#     '58': 7.06,
#     '64': 7.06,
#     '66': 7.07,
#     '68': 7.06,
#     '69': 7.03,
#     '72': 7.06,
#     '73': 7.07,
#     '74': 6.98,
#     '76': 6.97,
#     '77': 6.94,
#     '78': 7.07,
#     '81': 7.07,
#     '82': 7.04,
#     '83': 7.06,
#     '84': 7.15,
#     '85': 7.38},
#    'interceptions': {'7': 1.0},
#    'touches': {'4': 2.0,
#     '7': 3.0,
#     '9': 1.0,
#     '13': 1.0,
#     '15': 1.0,
#     '16': 1.0,
#     '18': 1.0,
#     '20': 1.0,
#     '21': 6.0,
#     '23': 1.0,
#     '24': 1.0,
#     '25': 1.0,
#     '26': 2.0,
#     '28': 2.0,
#     '29': 1.0,
#     '30': 4.0,
#     '32': 2.0,
#     '33': 2.0,
#     '34': 2.0,
#     '37': 1.0,
#     '38': 2.0,
#     '39': 3.0,
#     '40': 1.0,
#     '42': 1.0,
#     '44': 1.0,
#     '45': 2.0,
#     '49': 1.0,
#     '51': 1.0,
#     '53': 2.0,
#     '54': 2.0,
#     '55': 4.0,
#     '58': 2.0,
#     '64': 1.0,
#     '66': 2.0,
#     '68': 2.0,
#     '69': 1.0,
#     '72': 2.0,
#     '73': 2.0,
#     '74': 3.0,
#     '76': 5.0,
#     '78': 2.0,
#     '79': 1.0,
#     '81': 2.0,
#     '82': 1.0,
#     '83': 2.0,
#     '84': 1.0},
#    'passesTotal': {'4': 2.0,
#     '7': 2.0,
#     '9': 1.0,
#     '13': 1.0,
#     '16': 1.0,
#     '18': 1.0,
#     '21': 6.0,
#     '23': 1.0,
#     '24': 1.0,
#     '26': 1.0,
#     '28': 1.0,
#     '29': 1.0,
#     '34': 2.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 1.0,
#     '45': 1.0,
#     '54': 1.0,
#     '55': 3.0,
#     '58': 2.0,
#     '64': 1.0,
#     '66': 2.0,
#     '68': 1.0,
#     '72': 1.0,
#     '73': 2.0,
#     '76': 3.0,
#     '81': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 1.0,
#     '25': 1.0,
#     '30': 1.0,
#     '40': 1.0,
#     '42': 1.0,
#     '51': 1.0,
#     '53': 1.0,
#     '74': 1.0},
#    'passesAccurate': {'4': 1.0,
#     '7': 1.0,
#     '9': 1.0,
#     '13': 1.0,
#     '16': 1.0,
#     '18': 1.0,
#     '21': 6.0,
#     '23': 1.0,
#     '24': 1.0,
#     '26': 1.0,
#     '28': 1.0,
#     '29': 1.0,
#     '34': 1.0,
#     '37': 1.0,
#     '38': 1.0,
#     '39': 1.0,
#     '45': 1.0,
#     '54': 1.0,
#     '55': 2.0,
#     '58': 2.0,
#     '64': 1.0,
#     '66': 1.0,
#     '68': 1.0,
#     '72': 1.0,
#     '73': 2.0,
#     '76': 2.0,
#     '81': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 1.0},
#    'passesKey': {'26': 1.0, '84': 1.0},
#    'passSuccess': {'4': 50.0,
#     '7': 50.0,
#     '9': 100.0,
#     '13': 100.0,
#     '16': 100.0,
#     '18': 100.0,
#     '21': 100.0,
#     '23': 100.0,
#     '24': 100.0,
#     '26': 100.0,
#     '28': 100.0,
#     '29': 100.0,
#     '34': 50.0,
#     '37': 100.0,
#     '38': 100.0,
#     '39': 100.0,
#     '45': 100.0,
#     '54': 100.0,
#     '55': 66.67,
#     '58': 100.0,
#     '64': 100.0,
#     '66': 50.0,
#     '68': 100.0,
#     '72': 100.0,
#     '73': 100.0,
#     '76': 66.67,
#     '81': 100.0,
#     '82': 100.0,
#     '83': 100.0,
#     '84': 100.0,
#     '25': 0.0,
#     '30': 0.0,
#     '40': 0.0,
#     '42': 0.0,
#     '51': 0.0,
#     '53': 0.0,
#     '74': 0.0},
#    'aerialsTotal': {'30': 1.0},
#    'aerialsWon': {'30': 1.0},
#    'offensiveAerials': {'30': 1.0},
#    'cornersTotal': {'25': 1.0, '68': 1.0},
#    'throwInsTotal': {'30': 1.0,
#     '38': 1.0,
#     '45': 1.0,
#     '54': 1.0,
#     '55': 1.0,
#     '76': 2.0,
#     '78': 1.0,
#     '81': 1.0,
#     '83': 1.0},
#    'throwInsAccurate': {'30': 1.0,
#     '38': 1.0,
#     '54': 1.0,
#     '55': 1.0,
#     '76': 2.0,
#     '78': 1.0,
#     '81': 1.0,
#     '83': 1.0},
#    'foulsCommited': {'74': 1.0},
#    'tacklesTotal': {'32': 1.0,
#     '33': 1.0,
#     '44': 1.0,
#     '78': 1.0,
#     '28': 1.0,
#     '49': 1.0,
#     '77': 1.0,
#     '82': 1.0},
#    'tackleSuccessful': {'32': 1.0, '33': 1.0, '44': 1.0, '78': 1.0, '28': 1.0},
#    'tackleUnsuccesful': {'49': 1.0, '77': 1.0, '82': 1.0},
#    'tackleSuccess': {'32': 100.0,
#     '33': 100.0,
#     '44': 100.0,
#     '78': 100.0,
#     '28': 100.0,
#     '49': 0.0,
#     '77': 0.0,
#     '82': 0.0},
#    'dribbledPast': {'49': 1.0, '77': 1.0, '82': 1.0},
#    'dribblesWon': {'39': 1.0, '53': 1.0},
#    'dribblesAttempted': {'39': 2.0,
#     '53': 1.0,
#     '20': 1.0,
#     '30': 1.0,
#     '68': 1.0},
#    'dribblesLost': {'20': 1.0, '30': 1.0, '39': 1.0, '68': 1.0},
#    'dribbleSuccess': {'39': 50.0,
#     '53': 100.0,
#     '20': 0.0,
#     '30': 0.0,
#     '68': 0.0}}},
#  {'playerId': 345957,
#   'shirtNo': 5,
#   'name': 'Ibrahima Konaté',
#   'position': 'DC',
#   'height': 194,
#   'weight': 95,
#   'age': 24,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'1': 2.0,
#     '2': 1.0,
#     '3': 3.0,
#     '4': 2.0,
#     '6': 1.0,
#     '9': 2.0,
#     '12': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '16': 1.0,
#     '18': 2.0,
#     '20': 2.0,
#     '21': 4.0,
#     '22': 2.0,
#     '24': 2.0,
#     '26': 2.0,
#     '27': 2.0,
#     '28': 2.0,
#     '30': 1.0,
#     '32': 2.0,
#     '37': 2.0,
#     '38': 1.0,
#     '39': 1.0,
#     '40': 2.0,
#     '42': 2.0,
#     '47': 1.0,
#     '49': 1.0,
#     '50': 1.0,
#     '51': 1.0,
#     '54': 4.0,
#     '55': 1.0,
#     '56': 1.0,
#     '57': 2.0,
#     '58': 1.0,
#     '60': 1.0,
#     '63': 1.0,
#     '64': 1.0,
#     '65': 1.0,
#     '66': 2.0,
#     '67': 2.0,
#     '68': 1.0,
#     '69': 1.0,
#     '72': 1.0,
#     '73': 5.0,
#     '77': 1.0,
#     '78': 1.0,
#     '82': 2.0,
#     '93': 2.0,
#     '95': 2.0,
#     '96': 1.0,
#     '97': 1.0,
#     '99': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 6.12,
#     '2': 6.13,
#     '3': 6.13,
#     '4': 6.14,
#     '6': 6.14,
#     '7': 6.23,
#     '9': 6.41,
#     '10': 6.46,
#     '12': 6.59,
#     '13': 6.6,
#     '14': 6.6,
#     '16': 6.61,
#     '18': 6.62,
#     '20': 6.61,
#     '21': 6.62,
#     '22': 6.63,
#     '24': 6.63,
#     '26': 6.64,
#     '27': 6.64,
#     '28': 6.74,
#     '30': 6.74,
#     '32': 6.74,
#     '36': 6.76,
#     '37': 6.76,
#     '38': 6.77,
#     '39': 6.77,
#     '40': 6.77,
#     '42': 6.74,
#     '43': 6.88,
#     '47': 6.87,
#     '49': 6.87,
#     '50': 6.87,
#     '51': 6.88,
#     '54': 6.88,
#     '55': 6.88,
#     '56': 6.97,
#     '57': 6.98,
#     '58': 6.98,
#     '60': 6.98,
#     '63': 6.99,
#     '64': 6.99,
#     '65': 6.99,
#     '66': 6.99,
#     '67': 6.99,
#     '68': 7.0,
#     '69': 7.0,
#     '72': 7.0,
#     '73': 7.01,
#     '77': 6.98,
#     '78': 7.18,
#     '82': 7.18,
#     '85': 7.17,
#     '91': 7.15,
#     '93': 7.33,
#     '95': 7.33,
# ...
#     '40': 100.0,
#     '41': 100.0,
#     '42': 100.0,
#     '50': 100.0,
#     '51': 100.0,
#     '52': 100.0,
#     '54': 100.0,
#     '55': 100.0,
#     '62': 100.0,
#     '63': 100.0,
#     '64': 100.0,
#     '66': 100.0,
#     '68': 100.0,
#     '73': 100.0,
#     '74': 100.0,
#     '76': 50.0,
#     '10': 0.0,
#     '17': 0.0,
#     '57': 0.0},
#    'throwInsTotal': {'27': 1.0},
#    'throwInsAccurate': {'27': 1.0},
#    'tacklesTotal': {'74': 1.0, '45': 1.0},
#    'tackleSuccessful': {'74': 1.0},
#    'tackleUnsuccesful': {'45': 1.0},
#    'tackleSuccess': {'74': 100.0, '45': 0.0},
#    'dribbledPast': {'45': 1.0},
#    'dribblesWon': {'10': 1.0},
#    'dribblesAttempted': {'10': 1.0},
#    'dribbleSuccess': {'10': 100.0},
#    'dispossessed': {'28': 1.0}}},
#  {'playerId': 352825,
#   'shirtNo': 18,
#   'name': 'Cody Gakpo',
#   'position': 'FW',
#   'height': 193,
#   'weight': 76,
#   'age': 24,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 517340,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 85,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'2': 1.0,
#     '3': 3.0,
#     '9': 1.0,
#     '24': 4.0,
#     '27': 1.0,
#     '40': 2.0,
#     '47': 1.0,
#     '57': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '66': 1.0,
#     '67': 1.0,
#     '68': 1.0,
#     '72': 1.0,
#     '73': 1.0},
#    'ratings': {'0': 6.0,
#     '2': 6.0,
#     '3': 5.97,
#     '9': 5.97,
#     '13': 5.95,
#     '24': 5.96,
#     '25': 5.93,
#     '27': 5.93,
#     '35': 5.88,
#     '40': 5.88,
#     '47': 5.88,
#     '48': 5.85,
#     '57': 5.85,
#     '63': 5.85,
#     '65': 5.86,
#     '66': 5.86,
#     '67': 5.85,
#     '68': 5.9,
#     '71': 5.94,
#     '72': 5.94,
#     '73': 5.91,
#     '76': 5.89,
#     '83': 5.86,
#     '85': 5.91},
#    'shotsTotal': {'25': 1.0, '71': 1.0},
#    'shotsOffTarget': {'25': 1.0, '71': 1.0},
#    'touches': {'2': 1.0,
#     '3': 4.0,
#     '9': 1.0,
#     '12': 1.0,
#     '24': 4.0,
#     '25': 1.0,
#     '27': 1.0,
#     '35': 1.0,
#     '40': 2.0,
#     '47': 1.0,
#     '57': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '66': 1.0,
#     '67': 2.0,
#     '68': 4.0,
#     '71': 1.0,
#     '72': 1.0,
#     '73': 2.0,
#     '83': 1.0},
#    'passesTotal': {'2': 1.0,
#     '3': 3.0,
#     '9': 1.0,
#     '24': 4.0,
#     '27': 1.0,
#     '40': 2.0,
#     '47': 1.0,
#     '57': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '66': 1.0,
#     '72': 1.0,
#     '73': 1.0,
#     '67': 1.0,
#     '68': 1.0},
#    'passesAccurate': {'2': 1.0,
#     '3': 2.0,
#     '9': 1.0,
#     '24': 4.0,
#     '27': 1.0,
#     '40': 1.0,
#     '47': 1.0,
#     '57': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '66': 1.0,
#     '72': 1.0,
#     '73': 1.0},
#    'passSuccess': {'2': 100.0,
#     '3': 66.67,
#     '9': 100.0,
#     '24': 100.0,
#     '27': 100.0,
#     '40': 50.0,
#     '47': 100.0,
#     '57': 100.0,
#     '63': 100.0,
#     '65': 100.0,
#     '66': 100.0,
#     '72': 100.0,
#     '73': 100.0,
#     '67': 0.0,
#     '68': 0.0},
#    'aerialsTotal': {'13': 1.0, '35': 1.0, '76': 1.0},
#    'offensiveAerials': {'13': 1.0, '76': 1.0},
#    'defensiveAerials': {'35': 1.0},
#    'tacklesTotal': {'68': 1.0, '48': 1.0},
#    'tackleSuccessful': {'68': 1.0},
#    'tackleUnsuccesful': {'48': 1.0},
#    'tackleSuccess': {'68': 100.0, '48': 0.0},
#    'dribbledPast': {'48': 1.0},
#    'dispossessed': {'3': 1.0, '68': 1.0, '83': 1.0}}},
#  {'playerId': 377168,
#   'shirtNo': 7,
#   'name': 'Luis Díaz',
#   'position': 'FWL',
#   'height': 178,
#   'weight': 65,
#   'age': 27,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'3': 1.0,
#     '4': 1.0,
#     '8': 1.0,
#     '14': 1.0,
#     '15': 1.0,
#     '16': 1.0,
#     '17': 2.0,
#     '21': 1.0,
#     '22': 2.0,
#     '24': 2.0,
#     '26': 1.0,
#     '27': 1.0,
#     '29': 2.0,
#     '30': 2.0,
#     '34': 1.0,
#     '36': 1.0,
#     '39': 1.0,
#     '42': 1.0,
#     '45': 1.0,
#     '46': 1.0,
#     '50': 1.0,
#     '54': 1.0,
#     '55': 1.0,
#     '57': 1.0,
#     '60': 1.0,
#     '62': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '73': 3.0,
#     '76': 1.0,
#     '77': 1.0,
#     '81': 1.0,
#     '82': 1.0,
#     '84': 3.0,
#     '95': 1.0,
#     '97': 1.0,
#     '102': 1.0},
#    'ratings': {'0': 6.0,
#     '3': 6.0,
#     '4': 6.01,
#     '6': 5.99,
#     '8': 5.99,
#     '9': 5.96,
#     '11': 6.09,
#     '14': 6.1,
#     '15': 6.07,
#     '16': 6.07,
#     '17': 6.16,
#     '21': 6.13,
#     '22': 6.12,
#     '24': 6.13,
#     '26': 6.33,
#     '27': 6.34,
#     '29': 6.32,
#     '30': 6.33,
#     '32': 6.3,
#     '34': 6.29,
#     '35': 6.42,
#     '36': 6.39,
#     '38': 6.36,
#     '39': 6.36,
#     '42': 6.36,
#     '45': 6.4,
#     '46': 6.4,
#     '47': 6.37,
#     '50': 6.38,
#     '54': 6.38,
#     '55': 6.38,
#     '57': 6.35,
#     '60': 6.43,
#     '62': 6.43,
#     '63': 6.42,
#     '65': 6.5,
#     '70': 6.47,
#     '73': 6.48,
#     '76': 6.48,
#     '77': 6.45,
#     '79': 6.42,
#     '81': 6.49,
#     '82': 6.49,
#     '84': 6.57,
#     '86': 6.53,
#     '95': 6.54,
#     '97': 6.54,
#     '100': 6.71,
#     '102': 6.76},
#    'shotsTotal': {'16': 1.0,
#     '17': 1.0,
#     '26': 1.0,
#     '29': 1.0,
#     '77': 1.0,
#     '92': 1.0},
#    'shotsOffTarget': {'29': 1.0, '77': 1.0},
#    'shotsBlocked': {'16': 1.0, '17': 1.0, '26': 1.0, '92': 1.0},
#    'touches': {'3': 1.0,
#     '4': 1.0,
#     '8': 1.0,
#     '9': 1.0,
#     '11': 1.0,
#     '14': 1.0,
#     '15': 2.0,
#     '16': 2.0,
#     '17': 3.0,
#     '21': 4.0,
#     '22': 2.0,
#     '24': 2.0,
#     '26': 2.0,
#     '27': 1.0,
#     '29': 3.0,
#     '30': 2.0,
#     '32': 1.0,
#     '34': 1.0,
#     '35': 1.0,
#     '36': 2.0,
#     '38': 1.0,
#     '39': 1.0,
#     '41': 1.0,
#     '42': 1.0,
#     '45': 2.0,
#     '46': 1.0,
#     '47': 1.0,
#     '50': 1.0,
#     '54': 1.0,
#     '55': 1.0,
#     '57': 3.0,
#     '60': 1.0,
#     '62': 1.0,
#     '63': 2.0,
#     '65': 1.0,
#     '70': 2.0,
#     '73': 3.0,
#     '76': 1.0,
#     '77': 2.0,
#     '79': 2.0,
#     '81': 1.0,
#     '82': 1.0,
#     '84': 3.0,
#     '86': 1.0,
#     '92': 1.0,
#     '95': 1.0,
#     '97': 1.0,
#     '102': 1.0},
#    'passesTotal': {'3': 1.0,
#     '4': 1.0,
#     '8': 1.0,
#     '14': 1.0,
#     '15': 1.0,
#     '16': 1.0,
#     '17': 2.0,
#     '21': 1.0,
#     '22': 2.0,
#     '24': 2.0,
#     '26': 1.0,
#     '27': 1.0,
#     '29': 2.0,
#     '30': 2.0,
#     '36': 1.0,
#     '39': 1.0,
#     '42': 1.0,
#     '45': 1.0,
#     '46': 1.0,
#     '50': 1.0,
#     '54': 1.0,
#     '55': 1.0,
#     '57': 1.0,
#     '62': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '73': 3.0,
#     '76': 1.0,
#     '77': 1.0,
#     '82': 1.0,
#     '84': 1.0,
#     '95': 1.0,
#     '97': 1.0,
#     '102': 1.0,
#     '34': 1.0,
#     '60': 1.0,
#     '81': 1.0},
#    'passesAccurate': {'3': 1.0,
#     '4': 1.0,
#     '8': 1.0,
#     '14': 1.0,
#     '15': 1.0,
#     '16': 1.0,
#     '17': 2.0,
#     '21': 1.0,
#     '22': 1.0,
#     '24': 2.0,
#     '26': 1.0,
#     '27': 1.0,
#     '29': 2.0,
#     '30': 2.0,
#     '36': 1.0,
#     '39': 1.0,
#     '42': 1.0,
#     '45': 1.0,
#     '46': 1.0,
#     '50': 1.0,
#     '54': 1.0,
#     '55': 1.0,
#     '57': 1.0,
#     '62': 1.0,
#     '63': 1.0,
#     '65': 1.0,
#     '73': 3.0,
#     '76': 1.0,
#     '77': 1.0,
#     '82': 1.0,
#     '84': 1.0,
#     '95': 1.0,
#     '97': 1.0,
#     '102': 1.0},
#    'passesKey': {'65': 1.0},
#    'passSuccess': {'3': 100.0,
#     '4': 100.0,
#     '8': 100.0,
#     '14': 100.0,
#     '15': 100.0,
#     '16': 100.0,
#     '17': 100.0,
#     '21': 100.0,
#     '22': 50.0,
#     '24': 100.0,
#     '26': 100.0,
#     '27': 100.0,
#     '29': 100.0,
#     '30': 100.0,
#     '36': 100.0,
#     '39': 100.0,
#     '42': 100.0,
#     '45': 100.0,
#     '46': 100.0,
#     '50': 100.0,
#     '54': 100.0,
#     '55': 100.0,
#     '57': 100.0,
#     '62': 100.0,
#     '63': 100.0,
#     '65': 100.0,
#     '73': 100.0,
#     '76': 100.0,
#     '77': 100.0,
#     '82': 100.0,
#     '84': 100.0,
#     '95': 100.0,
#     '97': 100.0,
#     '102': 100.0,
#     '34': 0.0,
#     '60': 0.0,
#     '81': 0.0},
#    'aerialsTotal': {'17': 1.0, '60': 1.0, '81': 1.0, '6': 1.0},
#    'aerialsWon': {'17': 1.0, '60': 1.0, '81': 1.0},
#    'aerialSuccess': {'6': 0.0},
#    'offensiveAerials': {'6': 1.0, '17': 1.0, '60': 1.0},
#    'defensiveAerials': {'81': 1.0},
#    'cornersTotal': {'16': 1.0, '26': 1.0, '63': 1.0, '92': 1.0},
#    'tacklesTotal': {'11': 1.0, '35': 1.0},
#    'tackleSuccessful': {'11': 1.0, '35': 1.0},
#    'tackleSuccess': {'11': 100.0, '35': 100.0},
#    'dribblesAttempted': {'63': 1.0},
#    'dribblesLost': {'63': 1.0},
#    'dispossessed': {'15': 1.0, '21': 1.0, '57': 1.0}}},
#  {'playerId': 301455,
#   'shirtNo': 21,
#   'name': 'Kostas Tsimikas',
#   'position': 'Sub',
#   'height': 179,
#   'weight': 77,
#   'age': 27,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 85,
#   'subbedOutPlayerId': 424945,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'90': 2.0,
#     '91': 1.0,
#     '93': 1.0,
#     '95': 2.0,
#     '96': 2.0,
#     '99': 2.0},
#    'ratings': {'85': 6.0,
#     '90': 6.0,
#     '91': 5.99,
#     '93': 5.98,
#     '95': 5.97,
#     '96': 6.14,
#     '99': 6.23,
#     '100': 6.33,
#     '102': 6.36},
#    'shotsTotal': {'100': 1.0},
#    'shotsBlocked': {'100': 1.0},
#    'touches': {'90': 2.0,
#     '91': 1.0,
#     '93': 1.0,
#     '95': 2.0,
#     '96': 2.0,
#     '99': 2.0,
#     '100': 1.0},
#    'passesTotal': {'90': 2.0, '95': 1.0, '96': 1.0, '99': 1.0},
#    'passesAccurate': {'90': 1.0, '95': 1.0, '96': 1.0, '99': 1.0},
#    'passesKey': {'96': 1.0},
#    'passSuccess': {'90': 50.0, '95': 100.0, '96': 100.0, '99': 100.0},
#    'cornersTotal': {'90': 1.0, '95': 1.0},
#    'cornersAccurate': {'96': 1.0},
#    'throwInAccuracy': {'90': 0.0, '95': 0.0}}},
#  {'playerId': 369875,
#   'shirtNo': 8,
#   'name': 'Dominik Szoboszlai',
#   'position': 'Sub',
#   'height': 186,
#   'weight': 74,
#   'age': 23,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 77,
#   'subbedOutPlayerId': 363982,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'78': 1.0,
#     '79': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '85': 1.0,
#     '91': 1.0,
#     '92': 1.0,
#     '96': 1.0,
#     '99': 1.0,
#     '100': 1.0},
#    'ratings': {'77': 6.0,
#     '78': 5.98,
#     '79': 5.99,
#     '81': 5.95,
#     '82': 5.91,
#     '83': 5.9,
#     '85': 5.89,
#     '91': 5.89,
#     '92': 5.98,
#     '94': 6.01,
#     '96': 6.01,
#     '99': 6.02,
#     '100': 6.11,
#     '102': 6.14},
#    'shotsTotal': {'84': 1.0},
#    'shotsBlocked': {'84': 1.0},
#    'touches': {'78': 1.0,
#     '79': 1.0,
#     '81': 1.0,
#     '82': 2.0,
#     '83': 1.0,
#     '84': 1.0,
#     '85': 1.0,
#     '91': 1.0,
#     '92': 1.0,
#     '94': 1.0,
#     '96': 1.0,
#     '99': 1.0,
#     '100': 1.0},
#    'passesTotal': {'78': 1.0,
#     '79': 1.0,
#     '82': 1.0,
#     '91': 1.0,
#     '96': 1.0,
#     '99': 1.0,
#     '83': 1.0},
#    'passesAccurate': {'78': 1.0,
#     '79': 1.0,
#     '82': 1.0,
#     '91': 1.0,
#     '96': 1.0,
#     '99': 1.0},
#    'passSuccess': {'78': 100.0,
#     '79': 100.0,
#     '82': 100.0,
#     '91': 100.0,
#     '96': 100.0,
#     '99': 100.0,
#     '83': 0.0},
#    'aerialsTotal': {'78': 1.0},
#    'defensiveAerials': {'78': 1.0},
#    'cornersTotal': {'84': 1.0},
#    'cornersAccurate': {'92': 1.0},
#    'throwInAccuracy': {'84': 0.0},
#    'foulsCommited': {'82': 1.0},
#    'dispossessed': {'81': 1.0}}},
#  {'playerId': 86829,
#   'shirtNo': 3,
#   'name': 'Wataru Endo',
#   'position': 'Sub',
#   'height': 178,
#   'weight': 76,
#   'age': 31,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 61,
#   'subbedOutPlayerId': 450021,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'62': 2.0,
#     '63': 1.0,
#     '64': 2.0,
#     '65': 2.0,
#     '66': 1.0,
#     '70': 2.0,
#     '76': 3.0,
#     '82': 1.0,
#     '83': 1.0,
#     '89': 1.0,
#     '90': 3.0,
#     '91': 1.0,
#     '92': 1.0,
#     '95': 2.0,
#     '96': 1.0,
#     '98': 1.0,
#     '99': 1.0},
#    'ratings': {'61': 6.0,
#     '62': 6.0,
#     '63': 6.01,
#     '64': 6.0,
#     '65': 6.01,
#     '66': 6.13,
#     '70': 6.16,
#     '76': 6.17,
#     '82': 6.17,
#     '83': 6.18,
#     '89': 6.18,
#     '90': 6.19,
#     '91': 6.18,
#     '92': 6.19,
#     '93': 6.18,
#     '94': 6.23,
#     '95': 6.23,
#     '96': 6.23,
#     '98': 6.24,
#     '99': 6.2,
#     '100': 6.39,
#     '102': 6.42},
#    'clearances': {'94': 1.0},
#    'touches': {'62': 2.0,
#     '63': 1.0,
#     '64': 2.0,
#     '65': 2.0,
#     '66': 2.0,
#     '70': 4.0,
#     '76': 3.0,
#     '78': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '89': 1.0,
#     '90': 3.0,
#     '91': 1.0,
#     '92': 1.0,
#     '93': 1.0,
#     '94': 1.0,
#     '95': 2.0,
#     '96': 1.0,
#     '98': 1.0,
#     '99': 2.0,
#     '100': 1.0},
#    'passesTotal': {'62': 2.0,
#     '63': 1.0,
#     '64': 2.0,
#     '65': 2.0,
#     '76': 3.0,
#     '82': 1.0,
#     '83': 1.0,
#     '89': 1.0,
#     '90': 3.0,
#     '92': 1.0,
#     '95': 2.0,
#     '96': 1.0,
#     '98': 1.0,
#     '99': 1.0,
#     '66': 1.0,
#     '70': 2.0,
#     '91': 1.0},
#    'passesAccurate': {'62': 2.0,
#     '63': 1.0,
#     '64': 1.0,
#     '65': 2.0,
#     '76': 3.0,
#     '82': 1.0,
#     '83': 1.0,
#     '89': 1.0,
#     '90': 3.0,
#     '92': 1.0,
#     '95': 2.0,
#     '96': 1.0,
#     '98': 1.0,
#     '99': 1.0},
#    'passSuccess': {'62': 100.0,
#     '63': 100.0,
#     '64': 50.0,
#     '65': 100.0,
#     '76': 100.0,
#     '82': 100.0,
#     '83': 100.0,
#     '89': 100.0,
#     '90': 100.0,
#     '92': 100.0,
#     '95': 100.0,
#     '96': 100.0,
#     '98': 100.0,
#     '99': 100.0,
#     '66': 0.0,
#     '70': 0.0,
#     '91': 0.0},
#    'aerialsTotal': {'70': 1.0},
#    'aerialsWon': {'70': 1.0},
#    'defensiveAerials': {'70': 1.0},
#    'tacklesTotal': {'66': 1.0, '100': 1.0},
#    'tackleSuccessful': {'66': 1.0, '100': 1.0},
#    'tackleSuccess': {'66': 100.0, '100': 100.0},
#    'dribblesAttempted': {'93': 1.0},
#    'dribblesLost': {'93': 1.0}}},
#  {'playerId': 400828,
#   'shirtNo': 9,
#   'name': 'Darwin Núñez',
#   'position': 'Sub',
#   'height': 187,
#   'weight': 81,
#   'age': 24,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 61,
#   'subbedOutPlayerId': 115726,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'62': 1.0, '71': 1.0, '102': 1.0},
#    'ratings': {'61': 6.0,
#     '62': 5.98,
#     '65': 6.02,
#     '71': 6.1,
#     '72': 6.07,
#     '74': 6.1,
#     '96': 6.15,
#     '100': 7.3,
#     '102': 7.34},
#    'shotsTotal': {'65': 1.0, '74': 1.0, '91': 1.0, '96': 1.0, '100': 1.0},
#    'shotsOnTarget': {'100': 1.0},
#    'shotsOffTarget': {'65': 1.0, '74': 1.0, '96': 1.0},
#    'shotsBlocked': {'91': 1.0},
#    'touches': {'62': 2.0,
#     '65': 1.0,
#     '71': 1.0,
#     '72': 1.0,
#     '74': 1.0,
#     '91': 1.0,
#     '96': 1.0,
#     '100': 1.0,
#     '102': 1.0},
#    'passesTotal': {'71': 1.0, '102': 1.0, '62': 1.0},
#    'passesAccurate': {'71': 1.0, '102': 1.0},
#    'passesKey': {'71': 1.0},
#    'passSuccess': {'71': 100.0, '102': 100.0, '62': 0.0},
#    'aerialsTotal': {'96': 1.0, '100': 1.0},
#    'aerialsWon': {'96': 1.0, '100': 1.0},
#    'offensiveAerials': {'96': 1.0, '100': 1.0},
#    'dribblesAttempted': {'62': 1.0},
#    'dribblesLost': {'62': 1.0}}},
#  {'playerId': 517340,
#   'shirtNo': 76,
#   'name': 'Jayden Danns',
#   'position': 'Sub',
#   'height': 0,
#   'weight': 0,
#   'age': 18,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 85,
#   'subbedOutPlayerId': 352825,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {'possession': {'89': 1.0, '93': 1.0, '99': 1.0},
#    'ratings': {'85': 6.0,
#     '86': 5.87,
#     '89': 5.87,
#     '93': 5.87,
#     '98': 5.86,
#     '99': 5.86,
#     '100': 5.96,
#     '102': 5.99},
#    'touches': {'89': 1.0, '93': 1.0, '99': 1.0},
#    'passesTotal': {'89': 1.0, '93': 1.0, '99': 1.0},
#    'passesAccurate': {'89': 1.0, '93': 1.0, '99': 1.0},
#    'passSuccess': {'89': 100.0, '93': 100.0, '99': 100.0},
#    'aerialsTotal': {'86': 1.0, '98': 1.0},
#    'offensiveAerials': {'86': 1.0, '98': 1.0},
#    'foulsCommited': {'86': 1.0}}},
#  {'playerId': 73399,
#   'shirtNo': 13,
#   'name': 'Adrián',
#   'position': 'Sub',
#   'height': 190,
#   'weight': 80,
#   'age': 37,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {}},
#  {'playerId': 430019,
#   'shirtNo': 78,
#   'name': 'Jarell Quansah',
#   'position': 'Sub',
#   'height': 0,
#   'weight': 0,
#   'age': 21,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {}},
#  {'playerId': 492375,
#   'shirtNo': 53,
#   'name': 'James McConnell',
#   'position': 'Sub',
#   'height': 0,
#   'weight': 0,
#   'age': 19,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {}},
#  {'playerId': 492374,
#   'shirtNo': 67,
#   'name': 'Lewis Koumas',
#   'position': 'Sub',
#   'height': 0,
#   'weight': 0,
#   'age': 18,
#   'isManOfTheMatch': False,
#   'field': 'away',
#   'stats': {}}]

# %%
df_players = pd.DataFrame(match_players)
df_players.head()
# Out:
#    playerId  shirtNo                name position  height  weight  age  \
# 0     78386       26           Matz Sels       GK     188      75   32
# 1    386969        7       Neco Williams       DR     183      72   22
# 2    399490       32  Andrew Omobamidele       DC     188       0   21
# 3    445424       40             Murillo       DC     180      75   21
# 4    298659       15       Harry Toffolo       DL     183      71   28
#
#   isFirstEleven  isManOfTheMatch field  \
# 0          True            False  home
# 1          True            False  home
# 2          True            False  home
# 3          True            False  home
# 4          True            False  home
#
#                                                stats  subbedInPlayerId  \
# 0  {'totalSaves': {'96': 1.0}, 'parriedSafe': {'9...               NaN
# 1  {'possession': {'0': 1.0, '1': 1.0, '6': 1.0, ...               NaN
# 2  {'possession': {'1': 1.0, '13': 1.0, '20': 1.0...               NaN
# 3  {'possession': {'0': 2.0, '8': 1.0, '10': 1.0,...               NaN
# 4  {'possession': {'7': 1.0, '10': 1.0, '12': 1.0...               NaN
#
#   subbedOutPeriod  subbedOutExpandedMinute subbedInPeriod  \
# 0             NaN                      NaN            NaN
# 1             NaN                      NaN            NaN
# 2             NaN                      NaN            NaN
# 3             NaN                      NaN            NaN
# 4             NaN                      NaN            NaN
#
#    subbedInExpandedMinute  subbedOutPlayerId
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     NaN                NaN

# %%
df_players.columns
# Out:
# Index(['playerId', 'shirtNo', 'name', 'position', 'height', 'weight', 'age',
#        'isFirstEleven', 'isManOfTheMatch', 'field', 'stats',
#        'subbedInPlayerId', 'subbedOutPeriod', 'subbedOutExpandedMinute',
#        'subbedInPeriod', 'subbedInExpandedMinute', 'subbedOutPlayerId'],
#       dtype='object')

# %%
df_players = df_players[['playerId','name','position']]
df_players.head()
# Out:
#    playerId                name position
# 0     78386           Matz Sels       GK
# 1    386969       Neco Williams       DR
# 2    399490  Andrew Omobamidele       DC
# 3    445424             Murillo       DC
# 4    298659       Harry Toffolo       DL

# %%
# create a df from the match_events
df = pd.DataFrame(match_events)
df.head()
# Out:
#              id  eventId  minute  second  teamId     x     y  expandedMinute  \
# 0  2.653355e+09        2       0     0.0      26   0.0   0.0               0
# 1  2.653355e+09        2       0     0.0     174   0.0   0.0               0
# 2  2.653355e+09        3       0     0.0     174  50.0  50.0               0
# 3  2.653355e+09        4       0     3.0     174  33.9  56.0               0
# 4  2.653355e+09        5       0     5.0     174  44.7  73.0               0
#
#                                      period  \
# 0  {'value': 1, 'displayName': 'FirstHalf'}
# 1  {'value': 1, 'displayName': 'FirstHalf'}
# 2  {'value': 1, 'displayName': 'FirstHalf'}
# 3  {'value': 1, 'displayName': 'FirstHalf'}
# 4  {'value': 1, 'displayName': 'FirstHalf'}
#
#                                     type  ...  endY relatedEventId  \
# 0  {'value': 32, 'displayName': 'Start'}  ...   NaN            NaN
# 1  {'value': 32, 'displayName': 'Start'}  ...   NaN            NaN
# 2    {'value': 1, 'displayName': 'Pass'}  ...  53.4            NaN
# 3    {'value': 1, 'displayName': 'Pass'}  ...  72.6            NaN
# 4    {'value': 1, 'displayName': 'Pass'}  ...  67.5            NaN
#
#   relatedPlayerId  goalMouthZ  goalMouthY  isShot  blockedX  blockedY  \
# 0             NaN         NaN         NaN     NaN       NaN       NaN
# 1             NaN         NaN         NaN     NaN       NaN       NaN
# 2             NaN         NaN         NaN     NaN       NaN       NaN
# 3             NaN         NaN         NaN     NaN       NaN       NaN
# 4             NaN         NaN         NaN     NaN       NaN       NaN
#
#    cardType  isGoal
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['id', 'eventId', 'minute', 'second', 'teamId', 'x', 'y',
#        'expandedMinute', 'period', 'type', 'outcomeType', 'qualifiers',
#        'satisfiedEventsTypes', 'isTouch', 'playerId', 'endX', 'endY',
#        'relatedEventId', 'relatedPlayerId', 'goalMouthZ', 'goalMouthY',
#        'isShot', 'blockedX', 'blockedY', 'cardType', 'isGoal'],
#       dtype='object')

# %% [markdown]
# # Data cleansing

# %%
df_players.isnull().sum()
# Out:
# playerId    0
# name        0
# position    0
# dtype: int64

# %%
# check null values
df.isnull().sum()
# Out:
# id                         0
# eventId                    0
# minute                     0
# second                     3
# teamId                     0
# x                          0
# y                          0
# expandedMinute             0
# period                     0
# type                       0
# outcomeType                0
# qualifiers                 0
# satisfiedEventsTypes       0
# isTouch                    0
# playerId                  16
# endX                     554
# endY                     554
# relatedEventId          1587
# relatedPlayerId         1587
# goalMouthZ              1599
# goalMouthY              1599
# isShot                  1599
# blockedX                1608
# blockedY                1608
# cardType                1624
# isGoal                  1628
# dtype: int64

# %%
df.dropna(subset=['playerId'], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# eventId                    0
# minute                     0
# second                     3
# teamId                     0
# x                          0
# y                          0
# expandedMinute             0
# period                     0
# type                       0
# outcomeType                0
# qualifiers                 0
# satisfiedEventsTypes       0
# isTouch                    0
# playerId                   0
# endX                     538
# endY                     538
# relatedEventId          1571
# relatedPlayerId         1571
# goalMouthZ              1583
# goalMouthY              1583
# isShot                  1583
# blockedX                1592
# blockedY                1592
# cardType                1608
# isGoal                  1612
# dtype: int64

# %%
df = df.where(pd.notnull(df), None)

# %%
# merge the df with the df_players in player_id
df = df.merge(df_players, left_on='playerId', right_on='playerId', how='left')
df.head()
# Out:
#              id  eventId  minute  second  teamId     x     y  expandedMinute  \
# 0  2.653355e+09        3       0     0.0     174  50.0  50.0               0
# 1  2.653355e+09        4       0     3.0     174  33.9  56.0               0
# 2  2.653355e+09        5       0     5.0     174  44.7  73.0               0
# 3  2.653355e+09        6       0     6.0     174  53.4  67.7               0
# 4  2.653355e+09        7       0     8.0     174  25.0  69.0               0
#
#                                      period  \
# 0  {'value': 1, 'displayName': 'FirstHalf'}
# 1  {'value': 1, 'displayName': 'FirstHalf'}
# 2  {'value': 1, 'displayName': 'FirstHalf'}
# 3  {'value': 1, 'displayName': 'FirstHalf'}
# 4  {'value': 1, 'displayName': 'FirstHalf'}
#
#                                   type  ... relatedPlayerId goalMouthZ  \
# 0  {'value': 1, 'displayName': 'Pass'}  ...             NaN        NaN
# 1  {'value': 1, 'displayName': 'Pass'}  ...             NaN        NaN
# 2  {'value': 1, 'displayName': 'Pass'}  ...             NaN        NaN
# 3  {'value': 1, 'displayName': 'Pass'}  ...             NaN        NaN
# 4  {'value': 1, 'displayName': 'Pass'}  ...             NaN        NaN
#
#   goalMouthY  isShot  blockedX  blockedY  cardType  isGoal  \
# 0        NaN    None       NaN       NaN      None    None
# 1        NaN    None       NaN       NaN      None    None
# 2        NaN    None       NaN       NaN      None    None
# 3        NaN    None       NaN       NaN      None    None
# 4        NaN    None       NaN       NaN      None    None
#
#                  name  position
# 0          Ryan Yates       DMC
# 1             Murillo        DC
# 2   Nicolás Domínguez       DMC
# 3  Morgan Gibbs-White       AMC
# 4             Murillo        DC
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['id', 'eventId', 'minute', 'second', 'teamId', 'x', 'y',
#        'expandedMinute', 'period', 'type', 'outcomeType', 'qualifiers',
#        'satisfiedEventsTypes', 'isTouch', 'playerId', 'endX', 'endY',
#        'relatedEventId', 'relatedPlayerId', 'goalMouthZ', 'goalMouthY',
#        'isShot', 'blockedX', 'blockedY', 'cardType', 'isGoal', 'name',
#        'position'],
#       dtype='object')

# %%
df = df.rename(
    {
    
    'eventId': 'event_id',
    'expandedMinute': 'expanded_minute',
    'outcomeType': 'outcome_type',
    'isTouch': 'is_touch',
    'playerId': 'player_id',
    'teamId': 'team_id',
    'endX': 'end_x',
    'endY': 'end_y',
    'blockedX': 'blocked_x',
    'blockedY': 'blocked_y',
    'goalMouthY': 'goal_mouth_y',
    'goalMouthZ': 'goal_mouth_z',
    'isShot': 'is_shot',
    'cardType': 'card_type',
    'isGoal': 'is_goal',
    'name': 'player_name'
},
axis=1
)

# %%
# create new columns for the nested dictionaries
df['period_display_name'] = df['period'].apply(lambda x: x['displayName'])
df['type_display_name'] = df['type'].apply(lambda x: x['displayName'])
df['outcome_type_display_name'] = df['outcome_type'].apply(lambda x: x['displayName'])

# %%
df['type_display_name'].head()
# Out:
# 0    Pass
# 1    Pass
# 2    Pass
# 3    Pass
# 4    Pass
# Name: type_display_name, dtype: object

# %%
# renmove the nested dictionaries
df.drop(columns=['period', 'type', 'outcome_type'], inplace=True)

# %%
df = df[['id','player_name','event_id','minute','second','team_id','player_id','x','y','end_x','end_y',
         'qualifiers','is_touch','blocked_x','blocked_y','goal_mouth_y','goal_mouth_z','is_shot',
         'card_type','is_goal','type_display_name','outcome_type_display_name',
         'period_display_name']]

# %%
df.dtypes
# Out:
# id                           float64
# player_name                   object
# event_id                       int64
# minute                         int64
# second                       float64
# team_id                        int64
# player_id                    float64
# x                            float64
# y                            float64
# end_x                        float64
# end_y                        float64
# qualifiers                    object
# is_touch                        bool
# blocked_x                    float64
# blocked_y                    float64
# goal_mouth_y                 float64
# goal_mouth_z                 float64
# is_shot                       object
# card_type                     object
# is_goal                       object
# type_display_name             object
# outcome_type_display_name     object
# period_display_name           object
# dtype: object

# %%
df[['id', 'event_id', 'minute', 'team_id', 'player_id']] = df[['id', 'event_id', 'minute', 'team_id', 'player_id']].astype(np.int64)
# Out:
# C:\Users\imjos\AppData\Local\Temp\ipykernel_33992\452101415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['id', 'event_id', 'minute', 'team_id', 'player_id']] = df[['id', 'event_id', 'minute', 'team_id', 'player_id']].astype(np.int64)

# %%
df[['second', 'x', 'y', 'end_x', 'end_y']] = df[['second', 'x', 'y', 'end_x', 'end_y']].astype('float')
# Out:
# C:\Users\imjos\AppData\Local\Temp\ipykernel_33992\1649267266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['second', 'x', 'y', 'end_x', 'end_y']] = df[['second', 'x', 'y', 'end_x', 'end_y']].astype('float')

# %%
df[['is_shot','is_goal','card_type']] = df[['is_shot','is_goal','card_type']].astype('bool')
# Out:
# C:\Users\imjos\AppData\Local\Temp\ipykernel_33992\1341704250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['is_shot','is_goal','card_type']] = df[['is_shot','is_goal','card_type']].astype('bool')

# %%
df['is_goal'] = df['is_goal'].fillna(False)
df['is_shot'] = df['is_shot'].fillna(False)
# Out:
# C:\Users\imjos\AppData\Local\Temp\ipykernel_33992\1451954947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_goal'] = df['is_goal'].fillna(False)
# C:\Users\imjos\AppData\Local\Temp\ipykernel_33992\1451954947.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_shot'] = df['is_shot'].fillna(False)

# %%
# loop for to check the null values
for column in df.columns:
    if df[column].dtype == np.float64 or df[column].dtype == np.float32:
        df[column] = np.where(
            np.isnan(df[column]),
            None,
            df[column]
        )
# Out:
# C:\Users\imjos\AppData\Local\Temp\ipykernel_33992\910020158.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = np.where(

# %%
df
# Out:
#               id         player_name  event_id  minute second  team_id  \
# 0    -1641612537          Ryan Yates         3       0    0.0      174
# 1    -1641612481             Murillo         4       0    3.0      174
# 2    -1641612429   Nicolás Domínguez         5       0    5.0      174
# 3    -1641612409  Morgan Gibbs-White         6       0    6.0      174
# 4    -1641612329             Murillo         7       0    8.0      174
# ...          ...                 ...       ...     ...    ...      ...
# 1608 -1641362897  Callum Hudson-Odoi       716     100   39.0      174
# 1609 -1641362855           Luis Díaz      1095     100   40.0       26
# 1610 -1641362841        Darwin Núñez      1096     100   42.0       26
# 1611 -1641362735        Darwin Núñez      1097     100   45.0       26
# 1612 -1641359495              Felipe       718     100   48.0      174
#
#       player_id     x     y end_x  ... blocked_x blocked_y  goal_mouth_y  \
# 0        342830  50.0  50.0  33.0  ...      None      None          None
# 1        445424  33.9  56.0  45.9  ...      None      None          None
# 2        334653  44.7  73.0  52.4  ...      None      None          None
# 3        332867  53.4  67.7  33.2  ...      None      None          None
# 4        445424  25.0  69.0  12.6  ...      None      None          None
# ...         ...   ...   ...   ...  ...       ...       ...           ...
# 1608     350088  58.6  81.7  68.2  ...      None      None          None
# 1609     377168  27.7  59.3  36.6  ...      None      None          None
# 1610     400828  36.4  49.0  None  ...      None      None          None
# 1611     400828  36.0  55.2  42.0  ...      None      None          None
# 1612     102173   0.0   0.0  None  ...      None      None          None
#
#      goal_mouth_z is_shot card_type is_goal  type_display_name  \
# 0            None   False     False   False               Pass
# 1            None   False     False   False               Pass
# 2            None   False     False   False               Pass
# 3            None   False     False   False               Pass
# 4            None   False     False   False               Pass
# ...           ...     ...       ...     ...                ...
# 1608         None   False     False   False               Pass
# 1609         None   False     False   False               Pass
# 1610         None   False     False   False       BallRecovery
# 1611         None   False     False   False               Pass
# 1612         None   False      True   False               Card
#
#       outcome_type_display_name  period_display_name
# 0                    Successful            FirstHalf
# 1                    Successful            FirstHalf
# 2                    Successful            FirstHalf
# 3                    Successful            FirstHalf
# 4                    Successful            FirstHalf
# ...                         ...                  ...
# 1608               Unsuccessful           SecondHalf
# 1609                 Successful           SecondHalf
# 1610                 Successful           SecondHalf
# 1611                 Successful           SecondHalf
# 1612                 Successful           SecondHalf
#
# [1613 rows x 23 columns]
